# %%
# Imports all the required packages
import os
import argparse
import numpy as np
import os.path as osp
import pandas as pd
from sklearn.model_selection import train_test_split
from torch_geometric.data import (InMemoryDataset, download_url, extract_zip,Data)

import torch
#from torcheval.metrics import R2Score # To be implemented
import torch.nn as nn
import torch.nn.functional as F
from rdkit.Chem import DataStructs
from torch_geometric.loader import DataLoader

import torch.nn.functional as F
from torch.nn import Linear
from torch.nn import BatchNorm1d
import torch.optim as optim
from torch_geometric.nn import GCNConv,GraphConv,NNConv
from torch_geometric.nn import global_add_pool,knn_graph

try:
    import rdkit
    from rdkit import Chem
    from rdkit.Chem import AllChem
    from rdkit import rdBase
    from rdkit.Chem.rdchem import HybridizationType
    from rdkit import RDConfig
    from rdkit.Chem import ChemicalFeatures
    from rdkit.Chem.rdchem import BondType as BT
    from rdkit.Chem import Draw
    rdBase.DisableLog('rdApp.error')
except ImportError:
    print("rdkit = None")

# %%
# Model definition used for regression

class GCNlayer(nn.Module):
    
    def __init__(self, n_features, conv_dims, concat_dim, dropout):
        super(GCNlayer, self).__init__()
        self.n_features = n_features
        self.conv_dims = conv_dims
        self.concat_dim =  concat_dim
        self.dropout = dropout
        
        self.convs = nn.ModuleList()
        self.bns = nn.ModuleList()
        self.gru=nn.ModuleList()
        #args.conv_dims=[args.n_features,128,512,4092]
        self.lin0 = torch.nn.Linear(args.n_features, self.conv_dims[0]) # Changed from 128
        for i in range(len(self.conv_dims)-1):
            kk = nn.Sequential(Linear(6, self.conv_dims[i+1]), nn.ReLU(), Linear(self.conv_dims[i+1], self.conv_dims[i+1]*self.conv_dims[i+1]))
            conv = NNConv(self.conv_dims[i], self.conv_dims[i+1],kk,aggr='add')
            self.convs.append(conv)
            bn = BatchNorm1d(self.conv_dims[i+1])
            self.bns.append(bn)
            self.gru.append(nn.GRU(self.conv_dims[i+1], self.conv_dims[i+1])) # Changed
        self.conv_last = GraphConv(self.conv_dims[-1],self.conv_dims[-1])  # Last layer
        self.bn_last = BatchNorm1d(self.concat_dim)
        
    def forward(self, data):
        x, edge_index,edge_attr= data.x, data.edge_index,data.edge_attr # Changed . added edge_attr
        out = F.relu(self.lin0(x))
        h = out.unsqueeze(0)
        for i in range(len(self.convs)):
            m = F.relu(self.convs[i](out, edge_index,edge_attr)) # Changed . added edge_attr
            m = self.bns[i](m)
            out, h = self.gru[i](m.unsqueeze(0), h)  # Changed here. Added [i]
            out = out.squeeze(0)

        x = F.relu(self.conv_last(out, edge_index))# Changed . added edge_attr
        x = self.bn_last(x)
        x = global_add_pool(x,batch=data.batch)   #global_add_pool  cHANGED
        x = F.dropout(x, p=self.dropout, training=self.training)
        return x
    
class FClayer(nn.Module):
    
    def __init__(self, concat_dim, pred_dims, out_dim, dropout):
        super(FClayer, self).__init__()
        self.concat_dim = concat_dim
        self.pred_dims = pred_dims
        self.out_dim = out_dim
        self.dropout = dropout

        self.fcs = nn.ModuleList()
        self.bns = nn.ModuleList()
        # Linear layer has bias default=True
        for i in range(len(self.pred_dims)-1):
            fc = Linear(self.pred_dims[i], self.pred_dims[i+1])
            self.fcs.append(fc)
            bn = BatchNorm1d(self.pred_dims[i+1])
            self.bns.append(bn)
        self.fc_last = Linear(self.pred_dims[-1], self.out_dim)
    
    def forward(self, data):
        x = data
        for i in range(len(self.fcs)):
            x = F.relu(self.fcs[i](x))
            x = self.bns[i](x)
            x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.fc_last(x)
        return x

# Model definition  
class GCN_Model_reg(nn.Module):
    def __init__(self, args):
        super(GCN_Model_reg, self).__init__()
        
        # Convolutional Layer call
        self.conv = GCNlayer(args.n_features,args.conv_dims,args.concat_dim,args.dropout)

        # Fully connected layer call
        self.fc = FClayer(args.concat_dim,args.pred_dims,args.out_dim,args.dropout)
        
    def forward(self, data):
        x = self.conv(data) # Calling the convolutional layercpu
        x = self.fc(x) # Calling the Fully Connected Layer
        return x

# %%
# pytorch will be run on cpu
seed=200
paser = argparse.ArgumentParser()
args = paser.parse_args("")
np.random.seed(200)
torch.manual_seed(seed)
device=input("Enter cuda or cpu for device type")
device = torch.device(device)
#'cuda' if torch.cuda.is_available() else
device
# Out:
# device(type='cuda')

# %%
# Inputs required by the program
args.epoch = 500
args.lr = 0.0001
args.optim = 'Adam'
args.step_size = 25
args.gamma = 0.8
args.dropout = 0.1 # Tested for 0.2 but max r2 got 0.874. For 0.1 I got 0.897
args.n_features = 30  # Mass added else 29. Without atomic mass r2 0.899
args.concat_dim=128
args.conv_dims=[128,128,128] # Removed 1 layer
args.pred_dims=[128,512,128]
args.out_dim = 1

# %%
# encoding of all variables

def one_of_k_encoding(x, allowable_set):
    if x not in allowable_set:
        raise Exception("input {0} not in allowable set{1}:".format(x, allowable_set))
    return list(map(lambda s: x == s, allowable_set))

def one_of_k_encoding_unk(x, allowable_set):
    """Maps inputs not in the allowable set to the last element."""
    if x not in allowable_set:
        x = allowable_set[-1]
    return list(map(lambda s: x == s, allowable_set))
 
def get_intervals(l):
    """For list of lists, gets the cumulative products of the lengths"""
    intervals = len(l) * [0]
    # Initalize with 1
    intervals[0] = 1
    for k in range(1, len(l)):
        intervals[k] = (len(l[k]) + 1) * intervals[k - 1]
    return intervals

def safe_index(l, e):
    """Gets the index of e in l, providing an index of len(l) if not found"""
    try:
        return l.index(e)
    except:
        print("Add value to list of length {}".format(len(l)))
        return len(l)

# %%
# Atom features

possible_atom_list = ['H','C', 'O', 'F','N','Cl','P','S','Si','Br','I']  # Atomic symbol 11

aromatic=[0,1] # Aromatic 1
isring=[0,1]   # Ring 1
possible_numH_list = [0, 1, 2, 3, 4] # Total Number of bonded hydrogen atoms possible 5
num_bonds = [0, 1, 2, 3, 4, 5]  # Total Number of Hs a carbon can bond / Total number of bonds an atom make 6
possible_formal_charge_list = [-4,-3, -2, -1, 0, 1, 2, 3, 4]

# sp3d is removed because it doesnot vary according to the paper . Hybridization 4
possible_hybridization_list = [Chem.rdchem.HybridizationType.SP, Chem.rdchem.HybridizationType.SP2,Chem.rdchem.HybridizationType.SP3,Chem.rdchem.HybridizationType.SP3D2]

# storing all the features in a detailed list
reference_lists = [possible_atom_list, possible_numH_list,possible_formal_charge_list, num_bonds,aromatic,isring,possible_hybridization_list]

intervals = get_intervals(reference_lists)
print(intervals)
# Out:
# [1, 6, 60, 420, 1260, 3780, 18900]

# %% [markdown]
# - Total number of atom features used here is = 29

# %%
# Concatenate the entire feature list
def get_feature_list(atom):
    features = 5 * [0]
    features[0] = safe_index(possible_atom_list, atom.GetSymbol())
    features[1] = safe_index(possible_numH_list, atom.GetTotalNumHs())
    features[2] = safe_index(num_bonds, atom.GetImplicitValence())
    features[3] = safe_index(possible_formal_charge_list, atom.GetFormalCharge())    
    features[4] = safe_index(possible_hybridization_list, atom.GetHybridization())
    return features

# %%
def atom_features(atom,bool_id_feat=False,explicit_H=False):
    from rdkit import Chem
    results = np.array(one_of_k_encoding_unk(atom.GetSymbol(),possible_atom_list) + 
                           one_of_k_encoding_unk(atom.GetImplicitValence(), num_bonds) + 
                           [atom.GetFormalCharge()] + 
                           one_of_k_encoding_unk(atom.GetHybridization(), possible_hybridization_list) + 
                           [atom.GetIsAromatic()]+[atom.IsInRing()]+[atom.GetAtomicNum()])  # Atomic mass added  atom.GetAtomicNum() r2=0.907
    if not explicit_H:
        results = np.array(results.tolist() + one_of_k_encoding_unk(atom.GetTotalNumHs(),possible_numH_list))  # include neighbouring Hs
    return np.array(results)

# %%
# Bond Features

def bond_features(bond):
    from rdkit import Chem
    bt = bond.GetBondType()
    bond_feats = [bt == Chem.rdchem.BondType.SINGLE, bt == Chem.rdchem.BondType.DOUBLE,
                  bt == Chem.rdchem.BondType.TRIPLE, bt == Chem.rdchem.BondType.AROMATIC,
                  bond.GetIsConjugated(),bond.IsInRing()]
    
    # Include stereo bond features as it effects the boiling point
    #bond_feats = bond_feats + one_of_k_encoding_unk(str(bond.GetStereo()),["STEREONONE", "STEREOANY", "STEREOZ", "STEREOE"])
    return np.array(bond_feats)

# %% [markdown]
# - In the above bond features we have commented the stereo feature because we have seen that the smiles string has not been encoded to represent the information of the stereo state of the chemical formula.

# %%
# Create  atom pair of two connected molecules to pass messages

def get_bond_pair(mol):
    bonds = mol.GetBonds()
    res = [[],[]]
    for bond in bonds:
        res[0] += [bond.GetBeginAtomIdx(), bond.GetEndAtomIdx()]
        res[1] += [bond.GetEndAtomIdx(), bond.GetBeginAtomIdx()]
    return res

# create a graph data structure comprising of x=node_f, edge_index = bond pair info, 
# Here we are taking converted molecule from smiles as string
def mol2vec(mol):
    atoms = mol.GetAtoms()
    bonds = mol.GetBonds()
    node_f= [atom_features(atom) for atom in atoms]
    edge_index = get_bond_pair(mol)
    edge_attr = [bond_features(bond) for bond in bonds]

    for bond in bonds:
        edge_attr.append(bond_features(bond))
        
    # Graph data to be used
    # changes made in edge index format 
    data = Data(x=torch.tensor(node_f, dtype=torch.float),edge_index=torch.tensor(edge_index, dtype=torch.long),edge_attr=torch.tensor(edge_attr,dtype=torch.float))
    
    #print(data)
    return data,edge_attr,node_f

# %%
# Return mol info
def make_mol(df):
    mols = {}
    for i in range(df.shape[0]):
        mols[Chem.MolFromSmiles(df['Smiles'].iloc[i])] = df['Tm'].iloc[i]
    return mols

# %%
# Convert the dataset with X values and y values to be trained/tested
def make_vec(mols):
    X = []
    for m in mols.keys():
        if m is None:
            continue
        s,_,_=mol2vec(m) 
        X.append(s)
    for i, data in enumerate(X):
        y = list(mols.values())[i]
        data.y = torch.tensor([y], dtype=torch.float)
    return X

# %%
# Pca on graph data
#import umap
from sklearn.decomposition import PCA
def tsne_g(n,e):
    #print(e[0],e[1])
    model=PCA(n_components=20)
    # apply padding
    max_len_n = max(x.shape[0] for x in n)
    target_shape=np.array([0 for i in range(6)])
    for i in range(len(n)):
        c=max_len_n-n[i].shape[0]
        for j in range(c):
          n[i]=np.vstack((n[i], target_shape))
    #print(n)


    max_len_e = max(x.shape[0] for x in e)
    target_shape=np.array([0 for i in range(29)])
    for i in range(len(e)):
        c=max_len_n-e[i].shape[0]
        for j in range(c):
          e[i]=np.vstack((e[i], target_shape))
    #print(e)
    
    n=np.array(n)
    e=np.array(e)
    print(n.shape,e.shape)
    feature_matrix = np.concatenate((n,e), axis=2)

    # apply t-SNE
    #tsne = TSNE(n_components=5,perplexity=30)

    transformed_matrix = model.fit_transform(feature_matrix)

    print("Original feature matrix:")
    print(feature_matrix)
    print("\nTransformed feature matrix:")
    print(transformed_matrix)

# %%
def call_pca(mols):
    n=[]
    e=[]
    for m in mols.keys():
        _,i,j=mol2vec(m) 
        n.append(np.array(i))
        e.append(np.array(j))
    tsne_g(n,e)

# %% [markdown]
# ### Importing dataset

# %%
# Importing Dataset
dataset = pd.read_csv('../data/Tm_gc.csv')
dataset = pd.concat([dataset['Smiles'], dataset['Tm']], axis=1)
dataset
# Out:
#                                               Smiles      Tm
# 0                                 O=C(N)Nc1ccc(C)cc1  456.15
# 1       OCC(C(Oc1ccc(cc1)c2ccccc2)N3C=NC=N3)C(C)(C)C  391.15
# 2                      COC(=O)COc1nc(F)c(Cl)c(N)c1Cl  331.35
# 3                                 O=C(O)CNCP(=O)(O)O  533.15
# 4     O=N(=O)c1cc(ccc1C(=O)C2C(=O)CCCC2=O)S(=O)(=O)C  438.15
# ...                                              ...     ...
# 7044                CCC(C(=O)O)C1(O)CCC(CC1)c2ccccc2  430.15
# 7045                      OCC1CCC(O1)N2C=CC(=O)NC2=O  401.15
# 7046                  CC1CCC2(O)C(C)(C)C3CCC2(C)C1C3  329.15
# 7047                              CC1=CCC(CC1)C(=C)C  198.85
# 7048                              C1CC2C3CCC(C3)C2C1  350.15
#
# [7049 rows x 2 columns]

# %%
dataset.isnull().sum()
# Out:
# Smiles    0
# Tm        0
# dtype: int64

# %%
# Checking for duplicate values or duplicate smile string
duplicate = dataset[dataset.duplicated('Smiles')]
 
print("Duplicate Rows based on City :")
 
# Print the resultant Dataframe
print(duplicate)
# Out:
# Duplicate Rows based on City :
#                                   Smiles      Tm
# 111                  C([C@@H](C(=O)O)N)S  513.15
# 186             O=C(O)C(N)CSSCC(N)C(=O)O  533.65
# 197        CCOC(=O)C1(CCN(C)CC1)c2ccccc2  543.15
# 216   Oc1ccc2c(CCC3C2CCC4(C)C(O)CCC34)c1  494.65
# 322                       CSCCC(N)C(=O)O  556.15
# ...                                  ...     ...
# 6932        O=C(O)C1CCC(C)(C(=O)O)C1(C)C  460.15
# 6971    OCC1OC(C(O)C1O)N2C=Nc3c(N)ncnc23  530.40
# 6983                        C1CC2CCCC2C1  243.15
# 7035                 CC=Cc1ccc(O)c(OC)c1  306.65
# 7047                  CC1=CCC(CC1)C(=C)C  198.85
#
# [194 rows x 2 columns]

# %% [markdown]
# - So as we can see from the data there are 187 duplicate smiles strings. So we are removing all of them as we didnot find any relevant feature difference.

# %%
# Removing the duplicates
dataset.drop_duplicates(subset="Smiles", inplace=True)
dataset
# Out:
#                                               Smiles      Tm
# 0                                 O=C(N)Nc1ccc(C)cc1  456.15
# 1       OCC(C(Oc1ccc(cc1)c2ccccc2)N3C=NC=N3)C(C)(C)C  391.15
# 2                      COC(=O)COc1nc(F)c(Cl)c(N)c1Cl  331.35
# 3                                 O=C(O)CNCP(=O)(O)O  533.15
# 4     O=N(=O)c1cc(ccc1C(=O)C2C(=O)CCCC2=O)S(=O)(=O)C  438.15
# ...                                              ...     ...
# 7043         OCC1OC(OC2C(CO)OC(O)C(O)C2O)C(O)C(O)C1O  527.15
# 7044                CCC(C(=O)O)C1(O)CCC(CC1)c2ccccc2  430.15
# 7045                      OCC1CCC(O1)N2C=CC(=O)NC2=O  401.15
# 7046                  CC1CCC2(O)C(C)(C)C3CCC2(C)C1C3  329.15
# 7048                              C1CC2C3CCC(C3)C2C1  350.15
#
# [6855 rows x 2 columns]

# %% [markdown]
# - So after removing all the duplicates we are left with a dataset of shape (5089,2)

# %%
# Standardize the Boiling Point values
mean=dataset['Tm'].mean()
std=dataset['Tm'].std()
dataset['Tm']=(dataset['Tm']-mean)/std
dataset.describe()
print(mean,std)
# Out:
# 352.6430926331145 106.57952607847517

# %%
# Scale the dataset to values between 0 and 1

min_val=dataset['Tm'].min()
max_val=dataset['Tm'].max()
dataset['Tm']=(dataset['Tm']-min_val)/(max_val-min_val)
dataset.describe()
print(max_val,min_val)
# Out:
# 5.108925957936439 -2.5848594262866893

# %%
# Remove noise using Boxplot
# Finding the outliers 
import seaborn as sns

# Plot the boxplot of all columns
sns.boxplot(dataset['Tm'])

# Calculate the upper and lower bounds for each column using the interquartile range (IQR)
Q1 = dataset.quantile(0.25)
Q3 = dataset.quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 2 * IQR
upper_bound = Q3 + 2 * IQR

# Drop the rows containing the outliers in each column
dataset = dataset[~((dataset < lower_bound) | (dataset > upper_bound)).any(axis=1)]
# Out:
# C:\Users\kanad\AppData\Local\Temp\ipykernel_20628\390494786.py:9: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1 = dataset.quantile(0.25)
# C:\Users\kanad\AppData\Local\Temp\ipykernel_20628\390494786.py:10: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q3 = dataset.quantile(0.75)
# C:\Users\kanad\AppData\Local\Temp\ipykernel_20628\390494786.py:16: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   dataset = dataset[~((dataset < lower_bound) | (dataset > upper_bound)).any(axis=1)]
# C:\Users\kanad\AppData\Local\Temp\ipykernel_20628\390494786.py:16: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   dataset = dataset[~((dataset < lower_bound) | (dataset > upper_bound)).any(axis=1)]

# %%
# Train test split 
Train_set, Test_set = train_test_split(dataset, test_size=0.1, shuffle=True, random_state=seed)
Train_set = Train_set.reset_index(drop=True)
Test_set = Test_set.reset_index(drop=True)
val_set,_ = train_test_split(dataset, test_size=0.5, shuffle=True, random_state=seed)
val_set = val_set.reset_index(drop=True)
Train_set
# Out:
#                                                 Smiles        Tm
# 0           OCCNOc1ccc(Cl)cc1C(=O)Nc2ccc(cc2Cl)N(=O)=O  0.502439
# 1                       CCCCCCCCCCCCCCCCCC(=O)OCCC(C)C  0.270122
# 2                          CCCCCCCCCCOc1ccc(cc1)C(=O)O  0.377439
# 3                                         COC(=O)C(O)C  0.158537
# 4                                       Brc1cncc(Br)c1  0.375610
# ...                                                ...       ...
# 6162                              ClC(F)=C(Cl)C(F)(F)F  0.071951
# 6163                            O=C(O)C=Cc1ccc2OCOc2c1  0.535366
# 6164  CCC(CCC(C)C1CCC2C3CCC4CC(O)CCC4(C)C3CCC12C)C(C)C  0.414634
# 6165                                  O=N(=O)Nc1ccccc1  0.296707
# 6166                                         ClCC=CCCl  0.241463
#
# [6167 rows x 2 columns]

# %%
train_mols = make_mol(Train_set)
test_mols = make_mol(Test_set)
val_mols = make_mol(val_set)

train_X = make_vec(train_mols)
test_X = make_vec(test_mols)
val_X = make_vec(val_mols)

#call_pca(train_mols)

# %%
# Model activation

model = GCN_Model_reg(args)
model = model.to(device)

# %%
# Printing the model structure
print(model)
# Out:
# GCN_Model_reg(
#   (conv): GCNlayer(
#     (convs): ModuleList(
#       (0): NNConv(128, 128, aggr=add, nn=Sequential(
#         (0): Linear(in_features=6, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=16384, bias=True)
#       ))
#       (1): NNConv(128, 128, aggr=add, nn=Sequential(
#         (0): Linear(in_features=6, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=16384, bias=True)
#       ))
#     )
#     (bns): ModuleList(
#       (0): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (gru): ModuleList(
#       (0): GRU(128, 128)
#       (1): GRU(128, 128)
#     )
#     (lin0): Linear(in_features=30, out_features=128, bias=True)
#     (conv_last): GraphConv(128, 128)
#     (bn_last): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): FClayer(
#     (fcs): ModuleList(
#       (0): Linear(in_features=128, out_features=512, bias=True)
#       (1): Linear(in_features=512, out_features=128, bias=True)
#     )
#     (bns): ModuleList(
#       (0): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (fc_last): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
train_loader = DataLoader(train_X, batch_size=64, shuffle=True, drop_last=True)
val_loader=DataLoader(val_X, batch_size=len(val_X), shuffle=False, drop_last=True)
test_loader = DataLoader(test_X, batch_size=len(test_X), shuffle=False, drop_last=True)

# %%
# Save Checkpoint for model evaluation :
def save_checkpoint(epoch, model, optimizer, filename):
    state = {'Epoch': epoch,'State_dict': model.state_dict(),'optimizer': optimizer.state_dict()}
    torch.save(model, filename)

# %%
def R2_score(y_pred_i,Y):
    #Next we shall compute sigma_yy, which is the variance of y 
    sigma_yy = 0
    for i in range(Y.shape[0]): #access each row from the data set 
       y_i = float(Y[i])
       sigma_yy += (y_i-Y.mean())**2

    #now we can compute sum of squared residuals 
    #print('sigma_yy:', sigma_yy)
    sum_sq_residuals=0
    for i in range(Y.shape[0]): #access each row from the data set 
         y_i = Y[i] #access i-th row of y
         e_i = y_i - y_pred_i[i] #compute the difference between the actual observation y_i and prediction y_pred_i

         sum_sq_residuals += (e_i)**2

    #print('sum of squared residuals:', sum_sq_residuals)

    #Then we will compute the R^2 quantity
    R_sq = 1-sum_sq_residuals/sigma_yy
    return R_sq

# %%
#from sklearn.metrics import r2_score

def train(model, device, optimizer, train_loader, criterion, args):
    train_correct = 0
    train_total = 0
    epoch_train_loss = 0
    for i, data in enumerate(train_loader):
        data = data.to(device)
        targets = data.y.to(device)
        optimizer.zero_grad()
        outputs = model(data)
        
        #print(outputs)
        #print(targets)
        outputs.require_grad = False
        _, predicted = torch.max(outputs.data, 1)
        train_total += targets.size(0)

        correct_dim_output=outputs.squeeze() # done to reshape the outputs and match with targets
        score=R2_score(correct_dim_output.detach().cpu().numpy(), targets.detach().cpu().numpy())
        loss = criterion(correct_dim_output, targets)
        epoch_train_loss += loss.item()
        loss.backward()
        optimizer.step()
    epoch_train_loss /= len(train_loader)
    #print('- Loss : %.4f' % epoch_train_loss)
    return model, epoch_train_loss,score

# %%
def test(model, device, test_loader, args):
    train_total = 0
    y_score=[]
    y_test=[]
    with torch.no_grad():
     for i, data in enumerate(test_loader):
        data = data.to(device)
        targets = data.y.to(device)
        outputs = model(data)
        #print(outputs)
        #print(targets)
        outputs.require_grad = False
        _, predicted = torch.max(outputs.data, 1)
        train_total += targets.size(0)

        correct_dim_output=outputs.squeeze() # done to reshape the outputs and match with targets
        #y_score.append(outputs.cpu().numpy())
        #y_test.append(targets.cpu().numpy())
        test_score=R2_score(outputs.cpu().numpy(),targets.cpu().numpy())
        print("R2 Score Validation test set:",R2_score(outputs.cpu().numpy(),targets.cpu().numpy()))
    return test_score,model,outputs.cpu().numpy(),targets.cpu().numpy()

# %%
def experiment(model, train_loader, device, args):

    
    optimizer = optim.Adam(model.parameters(), lr=args.lr,weight_decay=5e-4) # Add l2 regularizer ??  # ,weight_decay=0.001
    criterion = nn.HuberLoss() # decide on type of losses later
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=args.step_size, gamma=args.gamma)
    
    list_train_loss = list()
    print('[Train]')
    counter=0
    train_r2_score=0.90
    val_r2_score=0.85
    for epoch in range(args.epoch):
        model.train()
        model, train_loss,score= train(model, device, optimizer, train_loader, criterion, args)
        print('- Epoch :', epoch+1,'- Loss : %.5f' % train_loss,'- Train R2 score : %.4f' % score)
        list_train_loss.append(train_loss)

        # Learning rate Updatation scheme when loss not decreasing
        if(epoch!=0):
            #print(train_loss[int(epoch)],train_loss[int(epoch-1)])
            if(round(list_train_loss[epoch],5)>=round(list_train_loss[epoch-1],5)):
                counter+=1
            else:
                counter=0
        if(train_loss<0.0002 and counter>=10):
           counter=0
           args.lr = optimizer.param_groups[0]['lr']*0.5
           print("\nLearning rate changed :",args.lr)
           optimizer = optim.Adam(model.parameters(), lr=args.lr,weight_decay=5e-4)
           scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=args.step_size, gamma=args.gamma)


        val_score,_,_,_=test(model, device,test_loader, args)

        # Saving the best model which has the highest R2 value
        if(val_score>val_r2_score):  # and score>train_r2_score  # Changed
            val_r2_score=val_score
            train_r2_score=score   
            print("Saving Model of score:",val_score,score)       
            save_checkpoint(epoch, model, optimizer, 'ECC_model_Tranfer.pt')  # Saving the best model
            
        scheduler.step()
    
    return args

# %%
result = vars(experiment(model, train_loader, device, args))
# Out:
# [Train]
# - Epoch : 1 - Loss : 0.09633 - Train R2 score : -6.4175
# R2 Score Validation test set: [-7.018512]
# - Epoch : 2 - Loss : 0.05736 - Train R2 score : -4.1399
# R2 Score Validation test set: [-4.4370537]
# - Epoch : 3 - Loss : 0.04226 - Train R2 score : -4.0902
# R2 Score Validation test set: [-3.9595318]
# - Epoch : 4 - Loss : 0.03445 - Train R2 score : -3.9574
# R2 Score Validation test set: [-2.483868]
# - Epoch : 5 - Loss : 0.02780 - Train R2 score : -2.4984
# R2 Score Validation test set: [-2.633867]
# - Epoch : 6 - Loss : 0.02436 - Train R2 score : -0.8417
# R2 Score Validation test set: [-1.5875807]
# - Epoch : 7 - Loss : 0.02207 - Train R2 score : -1.4324
# R2 Score Validation test set: [-1.5445361]
# - Epoch : 8 - Loss : 0.01988 - Train R2 score : -0.5444
# R2 Score Validation test set: [-1.6797571]
# - Epoch : 9 - Loss : 0.02012 - Train R2 score : -2.1272
# R2 Score Validation test set: [-1.3400137]
# - Epoch : 10 - Loss : 0.01862 - Train R2 score : -1.3068
# R2 Score Validation test set: [-0.8065876]
# - Epoch : 11 - Loss : 0.01677 - Train R2 score : -1.2919
# R2 Score Validation test set: [-0.8329897]
# - Epoch : 12 - Loss : 0.01661 - Train R2 score : -0.7174
# R2 Score Validation test set: [-0.81690204]
# - Epoch : 13 - Loss : 0.01502 - Train R2 score : -0.1785
# R2 Score Validation test set: [-0.6150181]
# - Epoch : 14 - Loss : 0.01429 - Train R2 score : -0.9150
# R2 Score Validation test set: [-0.8358959]
# - Epoch : 15 - Loss : 0.01440 - Train R2 score : 0.2127
# R2 Score Validation test set: [-0.69433475]
# - Epoch : 16 - Loss : 0.01316 - Train R2 score : -0.7544
# R2 Score Validation test set: [-0.32287848]
# - Epoch : 17 - Loss : 0.01273 - Train R2 score : -0.3952
# R2 Score Validation test set: [-0.37106383]
# - Epoch : 18 - Loss : 0.01229 - Train R2 score : -0.5787
# R2 Score Validation test set: [-0.1599251]
# - Epoch : 19 - Loss : 0.01142 - Train R2 score : -0.2293
# R2 Score Validation test set: [-0.30190873]
# - Epoch : 20 - Loss : 0.01151 - Train R2 score : -0.8578
# R2 Score Validation test set: [-0.18460822]
# - Epoch : 21 - Loss : 0.01028 - Train R2 score : 0.1357
# R2 Score Validation test set: [-0.07487166]
# - Epoch : 22 - Loss : 0.01002 - Train R2 score : -0.4813
# R2 Score Validation test set: [0.05341452]
# - Epoch : 23 - Loss : 0.01015 - Train R2 score : -0.0398
# R2 Score Validation test set: [-0.20068562]
# - Epoch : 24 - Loss : 0.00917 - Train R2 score : -0.2729
# R2 Score Validation test set: [0.02674514]
# - Epoch : 25 - Loss : 0.00938 - Train R2 score : -0.9197
# R2 Score Validation test set: [0.04782897]
# - Epoch : 26 - Loss : 0.00866 - Train R2 score : -0.2893
# R2 Score Validation test set: [0.13099402]
# - Epoch : 27 - Loss : 0.00840 - Train R2 score : -0.1082
# R2 Score Validation test set: [0.00429279]
# - Epoch : 28 - Loss : 0.00808 - Train R2 score : -0.0240
# R2 Score Validation test set: [0.07316738]
# - Epoch : 29 - Loss : 0.00787 - Train R2 score : 0.4832
# R2 Score Validation test set: [0.0425567]
# - Epoch : 30 - Loss : 0.00785 - Train R2 score : -0.3482
# R2 Score Validation test set: [0.1675294]
# - Epoch : 31 - Loss : 0.00724 - Train R2 score : 0.1181
# R2 Score Validation test set: [0.36975557]
# - Epoch : 32 - Loss : 0.00726 - Train R2 score : 0.2165
# R2 Score Validation test set: [0.03456062]
# - Epoch : 33 - Loss : 0.00695 - Train R2 score : -0.0755
# R2 Score Validation test set: [0.05545747]
# - Epoch : 34 - Loss : 0.00609 - Train R2 score : 0.2385
# R2 Score Validation test set: [0.16347605]
# - Epoch : 35 - Loss : 0.00676 - Train R2 score : 0.0592
# R2 Score Validation test set: [0.33131474]
# - Epoch : 36 - Loss : 0.00616 - Train R2 score : 0.2987
# R2 Score Validation test set: [0.20027155]
# - Epoch : 37 - Loss : 0.00648 - Train R2 score : 0.1550
# R2 Score Validation test set: [0.27567762]
# - Epoch : 38 - Loss : 0.00585 - Train R2 score : 0.4461
# R2 Score Validation test set: [0.26546293]
# - Epoch : 39 - Loss : 0.00600 - Train R2 score : 0.7429
# R2 Score Validation test set: [0.40283132]
# - Epoch : 40 - Loss : 0.00607 - Train R2 score : 0.3062
# R2 Score Validation test set: [0.41320014]
# - Epoch : 41 - Loss : 0.00570 - Train R2 score : 0.5732
# R2 Score Validation test set: [0.37307245]
# - Epoch : 42 - Loss : 0.00547 - Train R2 score : 0.5107
# R2 Score Validation test set: [0.38129252]
# - Epoch : 43 - Loss : 0.00542 - Train R2 score : 0.6007
# R2 Score Validation test set: [0.42386508]
# - Epoch : 44 - Loss : 0.00551 - Train R2 score : 0.0536
# R2 Score Validation test set: [0.4927644]
# - Epoch : 45 - Loss : 0.00498 - Train R2 score : 0.2396
# R2 Score Validation test set: [0.38576955]
# - Epoch : 46 - Loss : 0.00488 - Train R2 score : 0.2771
# R2 Score Validation test set: [0.41832614]
# - Epoch : 47 - Loss : 0.00460 - Train R2 score : 0.5566
# R2 Score Validation test set: [0.3685205]
# - Epoch : 48 - Loss : 0.00476 - Train R2 score : 0.5841
# R2 Score Validation test set: [0.53482914]
# - Epoch : 49 - Loss : 0.00448 - Train R2 score : 0.5044
# R2 Score Validation test set: [0.50439477]
# - Epoch : 50 - Loss : 0.00461 - Train R2 score : 0.6531
# R2 Score Validation test set: [0.53660715]
# - Epoch : 51 - Loss : 0.00437 - Train R2 score : 0.6574
# R2 Score Validation test set: [0.5279112]
# - Epoch : 52 - Loss : 0.00434 - Train R2 score : 0.6316
# R2 Score Validation test set: [0.50705385]
# - Epoch : 53 - Loss : 0.00421 - Train R2 score : 0.4595
# R2 Score Validation test set: [0.53488636]
# - Epoch : 54 - Loss : 0.00431 - Train R2 score : 0.2567
# R2 Score Validation test set: [0.46135795]
# - Epoch : 55 - Loss : 0.00411 - Train R2 score : 0.6255
# R2 Score Validation test set: [0.55292296]
# - Epoch : 56 - Loss : 0.00403 - Train R2 score : 0.5558
# R2 Score Validation test set: [0.60039335]
# - Epoch : 57 - Loss : 0.00403 - Train R2 score : 0.5242
# R2 Score Validation test set: [0.5140641]
# - Epoch : 58 - Loss : 0.00401 - Train R2 score : 0.6303
# R2 Score Validation test set: [0.5801538]
# - Epoch : 59 - Loss : 0.00405 - Train R2 score : 0.3509
# R2 Score Validation test set: [0.61108994]
# - Epoch : 60 - Loss : 0.00388 - Train R2 score : 0.7136
# R2 Score Validation test set: [0.56436974]
# - Epoch : 61 - Loss : 0.00377 - Train R2 score : 0.5437
# R2 Score Validation test set: [0.59707105]
# - Epoch : 62 - Loss : 0.00390 - Train R2 score : 0.6476
# R2 Score Validation test set: [0.58609617]
# - Epoch : 63 - Loss : 0.00358 - Train R2 score : 0.6981
# R2 Score Validation test set: [0.61747277]
# - Epoch : 64 - Loss : 0.00359 - Train R2 score : 0.3638
# R2 Score Validation test set: [0.5845656]
# - Epoch : 65 - Loss : 0.00362 - Train R2 score : 0.6543
# R2 Score Validation test set: [0.6572221]
# - Epoch : 66 - Loss : 0.00355 - Train R2 score : 0.5360
# R2 Score Validation test set: [0.636551]
# - Epoch : 67 - Loss : 0.00347 - Train R2 score : 0.3304
# R2 Score Validation test set: [0.659423]
# - Epoch : 68 - Loss : 0.00338 - Train R2 score : 0.6248
# R2 Score Validation test set: [0.6139464]
# - Epoch : 69 - Loss : 0.00351 - Train R2 score : 0.6918
# R2 Score Validation test set: [0.6345262]
# - Epoch : 70 - Loss : 0.00330 - Train R2 score : 0.6398
# R2 Score Validation test set: [0.607081]
# - Epoch : 71 - Loss : 0.00328 - Train R2 score : 0.6159
# R2 Score Validation test set: [0.6965798]
# - Epoch : 72 - Loss : 0.00316 - Train R2 score : 0.5996
# R2 Score Validation test set: [0.6948389]
# - Epoch : 73 - Loss : 0.00320 - Train R2 score : 0.6805
# R2 Score Validation test set: [0.647087]
# - Epoch : 74 - Loss : 0.00321 - Train R2 score : 0.6944
# R2 Score Validation test set: [0.65684205]
# - Epoch : 75 - Loss : 0.00318 - Train R2 score : 0.7257
# R2 Score Validation test set: [0.6543566]
# - Epoch : 76 - Loss : 0.00290 - Train R2 score : 0.4042
# R2 Score Validation test set: [0.6932888]
# - Epoch : 77 - Loss : 0.00298 - Train R2 score : 0.7174
# R2 Score Validation test set: [0.6478392]
# - Epoch : 78 - Loss : 0.00290 - Train R2 score : 0.7201
# R2 Score Validation test set: [0.7186289]
# - Epoch : 79 - Loss : 0.00302 - Train R2 score : 0.6601
# R2 Score Validation test set: [0.6732276]
# - Epoch : 80 - Loss : 0.00284 - Train R2 score : 0.5636
# R2 Score Validation test set: [0.6715932]
# - Epoch : 81 - Loss : 0.00285 - Train R2 score : 0.5584
# R2 Score Validation test set: [0.68513083]
# - Epoch : 82 - Loss : 0.00286 - Train R2 score : 0.6413
# R2 Score Validation test set: [0.7081611]
# - Epoch : 83 - Loss : 0.00294 - Train R2 score : 0.7416
# R2 Score Validation test set: [0.66052556]
# - Epoch : 84 - Loss : 0.00292 - Train R2 score : 0.8070
# R2 Score Validation test set: [0.70410204]
# - Epoch : 85 - Loss : 0.00284 - Train R2 score : 0.3143
# R2 Score Validation test set: [0.7126174]
# - Epoch : 86 - Loss : 0.00283 - Train R2 score : 0.7283
# R2 Score Validation test set: [0.694945]
# - Epoch : 87 - Loss : 0.00281 - Train R2 score : 0.7377
# R2 Score Validation test set: [0.7322438]
# - Epoch : 88 - Loss : 0.00283 - Train R2 score : 0.6881
# R2 Score Validation test set: [0.7043838]
# - Epoch : 89 - Loss : 0.00274 - Train R2 score : 0.7539
# R2 Score Validation test set: [0.7433721]
# - Epoch : 90 - Loss : 0.00276 - Train R2 score : 0.6702
# R2 Score Validation test set: [0.68966526]
# - Epoch : 91 - Loss : 0.00253 - Train R2 score : 0.7912
# R2 Score Validation test set: [0.7494687]
# - Epoch : 92 - Loss : 0.00258 - Train R2 score : 0.4993
# R2 Score Validation test set: [0.7092171]
# - Epoch : 93 - Loss : 0.00260 - Train R2 score : 0.7667
# R2 Score Validation test set: [0.72433245]
# - Epoch : 94 - Loss : 0.00257 - Train R2 score : 0.5770
# R2 Score Validation test set: [0.7600935]
# - Epoch : 95 - Loss : 0.00255 - Train R2 score : 0.6855
# R2 Score Validation test set: [0.73420954]
# - Epoch : 96 - Loss : 0.00258 - Train R2 score : 0.6618
# R2 Score Validation test set: [0.7352881]
# - Epoch : 97 - Loss : 0.00255 - Train R2 score : 0.2631
# R2 Score Validation test set: [0.74653757]
# - Epoch : 98 - Loss : 0.00255 - Train R2 score : 0.6052
# R2 Score Validation test set: [0.7432273]
# - Epoch : 99 - Loss : 0.00251 - Train R2 score : 0.5759
# R2 Score Validation test set: [0.75046504]
# - Epoch : 100 - Loss : 0.00255 - Train R2 score : 0.7149
# R2 Score Validation test set: [0.7185875]
# - Epoch : 101 - Loss : 0.00243 - Train R2 score : 0.7095
# R2 Score Validation test set: [0.7746172]
# - Epoch : 102 - Loss : 0.00238 - Train R2 score : 0.7600
# R2 Score Validation test set: [0.7456974]
# - Epoch : 103 - Loss : 0.00235 - Train R2 score : 0.6274
# R2 Score Validation test set: [0.7554223]
# - Epoch : 104 - Loss : 0.00234 - Train R2 score : 0.7369
# R2 Score Validation test set: [0.7222829]
# - Epoch : 105 - Loss : 0.00241 - Train R2 score : 0.6472
# R2 Score Validation test set: [0.7607506]
# - Epoch : 106 - Loss : 0.00231 - Train R2 score : 0.7692
# R2 Score Validation test set: [0.77533805]
# - Epoch : 107 - Loss : 0.00238 - Train R2 score : 0.7401
# R2 Score Validation test set: [0.7728294]
# - Epoch : 108 - Loss : 0.00232 - Train R2 score : 0.7149
# R2 Score Validation test set: [0.7471564]
# - Epoch : 109 - Loss : 0.00228 - Train R2 score : 0.7977
# R2 Score Validation test set: [0.75294507]
# - Epoch : 110 - Loss : 0.00221 - Train R2 score : 0.8647
# R2 Score Validation test set: [0.7544281]
# - Epoch : 111 - Loss : 0.00232 - Train R2 score : 0.6165
# R2 Score Validation test set: [0.7628855]
# - Epoch : 112 - Loss : 0.00229 - Train R2 score : 0.6996
# R2 Score Validation test set: [0.750658]
# - Epoch : 113 - Loss : 0.00218 - Train R2 score : 0.8096
# R2 Score Validation test set: [0.79617]
# - Epoch : 114 - Loss : 0.00217 - Train R2 score : 0.7272
# R2 Score Validation test set: [0.7558417]
# - Epoch : 115 - Loss : 0.00217 - Train R2 score : 0.8769
# R2 Score Validation test set: [0.77094567]
# - Epoch : 116 - Loss : 0.00211 - Train R2 score : 0.7822
# R2 Score Validation test set: [0.74761856]
# - Epoch : 117 - Loss : 0.00209 - Train R2 score : 0.8130
# R2 Score Validation test set: [0.7689248]
# - Epoch : 118 - Loss : 0.00215 - Train R2 score : 0.7012
# R2 Score Validation test set: [0.78470296]
# - Epoch : 119 - Loss : 0.00209 - Train R2 score : 0.6919
# R2 Score Validation test set: [0.75536704]
# - Epoch : 120 - Loss : 0.00212 - Train R2 score : 0.6267
# R2 Score Validation test set: [0.7610408]
# - Epoch : 121 - Loss : 0.00216 - Train R2 score : 0.5998
# R2 Score Validation test set: [0.7913537]
# - Epoch : 122 - Loss : 0.00207 - Train R2 score : 0.7637
# R2 Score Validation test set: [0.77739966]
# - Epoch : 123 - Loss : 0.00208 - Train R2 score : 0.7164
# R2 Score Validation test set: [0.7787958]
# - Epoch : 124 - Loss : 0.00209 - Train R2 score : 0.8152
# R2 Score Validation test set: [0.78662276]
# - Epoch : 125 - Loss : 0.00204 - Train R2 score : 0.7822
# R2 Score Validation test set: [0.76793164]
# - Epoch : 126 - Loss : 0.00201 - Train R2 score : 0.7369
# R2 Score Validation test set: [0.78484166]
# - Epoch : 127 - Loss : 0.00203 - Train R2 score : 0.6983
# R2 Score Validation test set: [0.8001118]
# - Epoch : 128 - Loss : 0.00195 - Train R2 score : 0.7850
# R2 Score Validation test set: [0.7827306]
# - Epoch : 129 - Loss : 0.00198 - Train R2 score : 0.7539
# R2 Score Validation test set: [0.7957487]
# - Epoch : 130 - Loss : 0.00201 - Train R2 score : 0.6674
# R2 Score Validation test set: [0.78795236]
# - Epoch : 131 - Loss : 0.00195 - Train R2 score : 0.7999
# R2 Score Validation test set: [0.79464793]
# - Epoch : 132 - Loss : 0.00195 - Train R2 score : 0.5471
# R2 Score Validation test set: [0.77900183]
# - Epoch : 133 - Loss : 0.00192 - Train R2 score : 0.8173
# R2 Score Validation test set: [0.7748686]
# - Epoch : 134 - Loss : 0.00190 - Train R2 score : 0.7039
# R2 Score Validation test set: [0.77853817]
# - Epoch : 135 - Loss : 0.00189 - Train R2 score : 0.7220
# R2 Score Validation test set: [0.80398315]
# - Epoch : 136 - Loss : 0.00191 - Train R2 score : 0.7960
# R2 Score Validation test set: [0.7745486]
# - Epoch : 137 - Loss : 0.00183 - Train R2 score : 0.6219
# R2 Score Validation test set: [0.7904274]
# - Epoch : 138 - Loss : 0.00188 - Train R2 score : 0.8324
# R2 Score Validation test set: [0.8084241]
# - Epoch : 139 - Loss : 0.00186 - Train R2 score : 0.6944
# R2 Score Validation test set: [0.7972069]
# - Epoch : 140 - Loss : 0.00183 - Train R2 score : 0.6495
# R2 Score Validation test set: [0.7970532]
# - Epoch : 141 - Loss : 0.00188 - Train R2 score : 0.8167
# R2 Score Validation test set: [0.8012312]
# - Epoch : 142 - Loss : 0.00186 - Train R2 score : 0.8294
# R2 Score Validation test set: [0.7994313]
# - Epoch : 143 - Loss : 0.00185 - Train R2 score : 0.8093
# R2 Score Validation test set: [0.8037546]
# - Epoch : 144 - Loss : 0.00176 - Train R2 score : 0.8246
# R2 Score Validation test set: [0.7986595]
# - Epoch : 145 - Loss : 0.00179 - Train R2 score : 0.6606
# R2 Score Validation test set: [0.79901856]
# - Epoch : 146 - Loss : 0.00172 - Train R2 score : 0.8696
# R2 Score Validation test set: [0.7941034]
# - Epoch : 147 - Loss : 0.00183 - Train R2 score : 0.5629
# R2 Score Validation test set: [0.80175316]
# - Epoch : 148 - Loss : 0.00179 - Train R2 score : 0.7722
# R2 Score Validation test set: [0.79849684]
# - Epoch : 149 - Loss : 0.00173 - Train R2 score : 0.8391
# R2 Score Validation test set: [0.7980406]
# - Epoch : 150 - Loss : 0.00175 - Train R2 score : 0.8309
# R2 Score Validation test set: [0.7913755]
# - Epoch : 151 - Loss : 0.00168 - Train R2 score : 0.7759
# R2 Score Validation test set: [0.7955357]
# - Epoch : 152 - Loss : 0.00173 - Train R2 score : 0.7923
# R2 Score Validation test set: [0.8128531]
# - Epoch : 153 - Loss : 0.00169 - Train R2 score : 0.7993
# R2 Score Validation test set: [0.80189496]
# - Epoch : 154 - Loss : 0.00167 - Train R2 score : 0.7499
# R2 Score Validation test set: [0.8042529]
# - Epoch : 155 - Loss : 0.00169 - Train R2 score : 0.8185
# R2 Score Validation test set: [0.8116461]
# - Epoch : 156 - Loss : 0.00164 - Train R2 score : 0.7574
# R2 Score Validation test set: [0.80897737]
# - Epoch : 157 - Loss : 0.00163 - Train R2 score : 0.8104
# R2 Score Validation test set: [0.81261885]
# - Epoch : 158 - Loss : 0.00160 - Train R2 score : 0.8369
# R2 Score Validation test set: [0.8064794]
# - Epoch : 159 - Loss : 0.00166 - Train R2 score : 0.8030
# R2 Score Validation test set: [0.7953153]
# - Epoch : 160 - Loss : 0.00164 - Train R2 score : 0.8114
# R2 Score Validation test set: [0.8133542]
# - Epoch : 161 - Loss : 0.00164 - Train R2 score : 0.7631
# R2 Score Validation test set: [0.7789637]
# - Epoch : 162 - Loss : 0.00165 - Train R2 score : 0.7135
# R2 Score Validation test set: [0.8035029]
# - Epoch : 163 - Loss : 0.00163 - Train R2 score : 0.8146
# R2 Score Validation test set: [0.80827665]
# - Epoch : 164 - Loss : 0.00157 - Train R2 score : 0.8282
# R2 Score Validation test set: [0.81576633]
# - Epoch : 165 - Loss : 0.00164 - Train R2 score : 0.8483
# R2 Score Validation test set: [0.8048199]
# - Epoch : 166 - Loss : 0.00156 - Train R2 score : 0.8332
# R2 Score Validation test set: [0.79376024]
# - Epoch : 167 - Loss : 0.00161 - Train R2 score : 0.8448
# R2 Score Validation test set: [0.8176465]
# - Epoch : 168 - Loss : 0.00158 - Train R2 score : 0.8716
# R2 Score Validation test set: [0.8115846]
# - Epoch : 169 - Loss : 0.00156 - Train R2 score : 0.8769
# R2 Score Validation test set: [0.8151649]
# - Epoch : 170 - Loss : 0.00152 - Train R2 score : 0.8882
# R2 Score Validation test set: [0.80638254]
# - Epoch : 171 - Loss : 0.00159 - Train R2 score : 0.7993
# R2 Score Validation test set: [0.8038723]
# - Epoch : 172 - Loss : 0.00149 - Train R2 score : 0.8265
# R2 Score Validation test set: [0.8132535]
# - Epoch : 173 - Loss : 0.00150 - Train R2 score : 0.8008
# R2 Score Validation test set: [0.80177903]
# - Epoch : 174 - Loss : 0.00156 - Train R2 score : 0.7448
# R2 Score Validation test set: [0.807515]
# - Epoch : 175 - Loss : 0.00151 - Train R2 score : 0.5712
# R2 Score Validation test set: [0.7988142]
# - Epoch : 176 - Loss : 0.00153 - Train R2 score : 0.7836
# R2 Score Validation test set: [0.81381834]
# - Epoch : 177 - Loss : 0.00150 - Train R2 score : 0.8407
# R2 Score Validation test set: [0.8061122]
# - Epoch : 178 - Loss : 0.00148 - Train R2 score : 0.8394
# R2 Score Validation test set: [0.81134707]
# - Epoch : 179 - Loss : 0.00151 - Train R2 score : 0.8865
# R2 Score Validation test set: [0.81589806]
# - Epoch : 180 - Loss : 0.00142 - Train R2 score : 0.7975
# R2 Score Validation test set: [0.81391895]
# - Epoch : 181 - Loss : 0.00144 - Train R2 score : 0.7282
# R2 Score Validation test set: [0.8161552]
# - Epoch : 182 - Loss : 0.00138 - Train R2 score : 0.7449
# R2 Score Validation test set: [0.8146244]
# - Epoch : 183 - Loss : 0.00143 - Train R2 score : 0.7924
# R2 Score Validation test set: [0.8125074]
# - Epoch : 184 - Loss : 0.00147 - Train R2 score : 0.7976
# R2 Score Validation test set: [0.8121135]
# - Epoch : 185 - Loss : 0.00142 - Train R2 score : 0.8426
# R2 Score Validation test set: [0.82018435]
# - Epoch : 186 - Loss : 0.00145 - Train R2 score : 0.8811
# R2 Score Validation test set: [0.8047792]
# - Epoch : 187 - Loss : 0.00138 - Train R2 score : 0.8186
# R2 Score Validation test set: [0.81964624]
# - Epoch : 188 - Loss : 0.00143 - Train R2 score : 0.7565
# R2 Score Validation test set: [0.8213364]
# - Epoch : 189 - Loss : 0.00144 - Train R2 score : 0.8028
# R2 Score Validation test set: [0.8112602]
# - Epoch : 190 - Loss : 0.00139 - Train R2 score : 0.8668
# R2 Score Validation test set: [0.8303211]
# - Epoch : 191 - Loss : 0.00139 - Train R2 score : 0.8649
# R2 Score Validation test set: [0.82172704]
# - Epoch : 192 - Loss : 0.00141 - Train R2 score : 0.8383
# R2 Score Validation test set: [0.8194227]
# - Epoch : 193 - Loss : 0.00134 - Train R2 score : 0.7687
# R2 Score Validation test set: [0.8215728]
# - Epoch : 194 - Loss : 0.00140 - Train R2 score : 0.8354
# R2 Score Validation test set: [0.80061495]
# - Epoch : 195 - Loss : 0.00137 - Train R2 score : 0.8062
# R2 Score Validation test set: [0.816018]
# - Epoch : 196 - Loss : 0.00138 - Train R2 score : 0.8192
# R2 Score Validation test set: [0.81389505]
# - Epoch : 197 - Loss : 0.00138 - Train R2 score : 0.8224
# R2 Score Validation test set: [0.81725127]
# - Epoch : 198 - Loss : 0.00137 - Train R2 score : 0.8966
# R2 Score Validation test set: [0.82791233]
# - Epoch : 199 - Loss : 0.00138 - Train R2 score : 0.8284
# R2 Score Validation test set: [0.8228077]
# - Epoch : 200 - Loss : 0.00138 - Train R2 score : 0.8493
# R2 Score Validation test set: [0.8185096]
# - Epoch : 201 - Loss : 0.00133 - Train R2 score : 0.7967
# R2 Score Validation test set: [0.81465656]
# - Epoch : 202 - Loss : 0.00132 - Train R2 score : 0.8626
# R2 Score Validation test set: [0.8074515]
# - Epoch : 203 - Loss : 0.00131 - Train R2 score : 0.8900
# R2 Score Validation test set: [0.8215249]
# - Epoch : 204 - Loss : 0.00134 - Train R2 score : 0.8884
# R2 Score Validation test set: [0.82314146]
# - Epoch : 205 - Loss : 0.00130 - Train R2 score : 0.7034
# R2 Score Validation test set: [0.8293874]
# - Epoch : 206 - Loss : 0.00128 - Train R2 score : 0.7441
# R2 Score Validation test set: [0.81006837]
# - Epoch : 207 - Loss : 0.00130 - Train R2 score : 0.8320
# R2 Score Validation test set: [0.82500064]
# - Epoch : 208 - Loss : 0.00126 - Train R2 score : 0.8863
# R2 Score Validation test set: [0.82815725]
# - Epoch : 209 - Loss : 0.00127 - Train R2 score : 0.8754
# R2 Score Validation test set: [0.81768167]
# - Epoch : 210 - Loss : 0.00123 - Train R2 score : 0.8675
# R2 Score Validation test set: [0.82678497]
# - Epoch : 211 - Loss : 0.00122 - Train R2 score : 0.8997
# R2 Score Validation test set: [0.8298514]
# - Epoch : 212 - Loss : 0.00120 - Train R2 score : 0.9057
# R2 Score Validation test set: [0.8196531]
# - Epoch : 213 - Loss : 0.00127 - Train R2 score : 0.7903
# R2 Score Validation test set: [0.83023924]
# - Epoch : 214 - Loss : 0.00122 - Train R2 score : 0.8762
# R2 Score Validation test set: [0.8289287]
# - Epoch : 215 - Loss : 0.00125 - Train R2 score : 0.9220
# R2 Score Validation test set: [0.81836224]
# - Epoch : 216 - Loss : 0.00122 - Train R2 score : 0.7845
# R2 Score Validation test set: [0.8257588]
# - Epoch : 217 - Loss : 0.00125 - Train R2 score : 0.8762
# R2 Score Validation test set: [0.8409676]
# - Epoch : 218 - Loss : 0.00123 - Train R2 score : 0.8137
# R2 Score Validation test set: [0.8342075]
# - Epoch : 219 - Loss : 0.00122 - Train R2 score : 0.8591
# R2 Score Validation test set: [0.8233621]
# - Epoch : 220 - Loss : 0.00119 - Train R2 score : 0.8143
# R2 Score Validation test set: [0.83880186]
# - Epoch : 221 - Loss : 0.00121 - Train R2 score : 0.8322
# R2 Score Validation test set: [0.8302181]
# - Epoch : 222 - Loss : 0.00125 - Train R2 score : 0.8606
# R2 Score Validation test set: [0.83412623]
# - Epoch : 223 - Loss : 0.00118 - Train R2 score : 0.9327
# R2 Score Validation test set: [0.83937675]
# - Epoch : 224 - Loss : 0.00122 - Train R2 score : 0.8758
# R2 Score Validation test set: [0.8247063]
# - Epoch : 225 - Loss : 0.00122 - Train R2 score : 0.8773
# R2 Score Validation test set: [0.83634627]
# - Epoch : 226 - Loss : 0.00117 - Train R2 score : 0.7295
# R2 Score Validation test set: [0.83138645]
# - Epoch : 227 - Loss : 0.00116 - Train R2 score : 0.8937
# R2 Score Validation test set: [0.82352626]
# - Epoch : 228 - Loss : 0.00113 - Train R2 score : 0.9149
# R2 Score Validation test set: [0.83509433]
# - Epoch : 229 - Loss : 0.00113 - Train R2 score : 0.8786
# R2 Score Validation test set: [0.8424673]
# - Epoch : 230 - Loss : 0.00112 - Train R2 score : 0.9171
# R2 Score Validation test set: [0.83889407]
# - Epoch : 231 - Loss : 0.00115 - Train R2 score : 0.9029
# R2 Score Validation test set: [0.83526176]
# - Epoch : 232 - Loss : 0.00111 - Train R2 score : 0.8721
# R2 Score Validation test set: [0.8466786]
# - Epoch : 233 - Loss : 0.00115 - Train R2 score : 0.8990
# R2 Score Validation test set: [0.8413682]
# - Epoch : 234 - Loss : 0.00116 - Train R2 score : 0.7934
# R2 Score Validation test set: [0.8371512]
# - Epoch : 235 - Loss : 0.00110 - Train R2 score : 0.7966
# R2 Score Validation test set: [0.83230263]
# - Epoch : 236 - Loss : 0.00110 - Train R2 score : 0.9245
# R2 Score Validation test set: [0.84508896]
# - Epoch : 237 - Loss : 0.00112 - Train R2 score : 0.8843
# R2 Score Validation test set: [0.8324297]
# - Epoch : 238 - Loss : 0.00114 - Train R2 score : 0.8125
# R2 Score Validation test set: [0.8372499]
# - Epoch : 239 - Loss : 0.00112 - Train R2 score : 0.9275
# R2 Score Validation test set: [0.84005266]
# - Epoch : 240 - Loss : 0.00115 - Train R2 score : 0.8855
# R2 Score Validation test set: [0.8409197]
# - Epoch : 241 - Loss : 0.00112 - Train R2 score : 0.7731
# R2 Score Validation test set: [0.84269667]
# - Epoch : 242 - Loss : 0.00107 - Train R2 score : 0.8673
# R2 Score Validation test set: [0.8314469]
# - Epoch : 243 - Loss : 0.00108 - Train R2 score : 0.8333
# R2 Score Validation test set: [0.8412414]
# - Epoch : 244 - Loss : 0.00108 - Train R2 score : 0.9222
# R2 Score Validation test set: [0.8395388]
# - Epoch : 245 - Loss : 0.00112 - Train R2 score : 0.8778
# R2 Score Validation test set: [0.8296716]
# - Epoch : 246 - Loss : 0.00108 - Train R2 score : 0.8170
# R2 Score Validation test set: [0.8412647]
# - Epoch : 247 - Loss : 0.00108 - Train R2 score : 0.9184
# R2 Score Validation test set: [0.8345597]
# - Epoch : 248 - Loss : 0.00106 - Train R2 score : 0.7375
# R2 Score Validation test set: [0.83686024]
# - Epoch : 249 - Loss : 0.00109 - Train R2 score : 0.8338
# R2 Score Validation test set: [0.83804333]
# - Epoch : 250 - Loss : 0.00104 - Train R2 score : 0.8848
# R2 Score Validation test set: [0.84009063]
# - Epoch : 251 - Loss : 0.00102 - Train R2 score : 0.8951
# R2 Score Validation test set: [0.8425938]
# - Epoch : 252 - Loss : 0.00104 - Train R2 score : 0.9031
# R2 Score Validation test set: [0.8330065]
# - Epoch : 253 - Loss : 0.00106 - Train R2 score : 0.8800
# R2 Score Validation test set: [0.8292909]
# - Epoch : 254 - Loss : 0.00103 - Train R2 score : 0.8507
# R2 Score Validation test set: [0.8394983]
# - Epoch : 255 - Loss : 0.00103 - Train R2 score : 0.8859
# R2 Score Validation test set: [0.8434132]
# - Epoch : 256 - Loss : 0.00104 - Train R2 score : 0.9303
# R2 Score Validation test set: [0.82838714]
# - Epoch : 257 - Loss : 0.00105 - Train R2 score : 0.9133
# R2 Score Validation test set: [0.84731656]
# - Epoch : 258 - Loss : 0.00103 - Train R2 score : 0.8880
# R2 Score Validation test set: [0.8410803]
# - Epoch : 259 - Loss : 0.00103 - Train R2 score : 0.8383
# R2 Score Validation test set: [0.8415164]
# - Epoch : 260 - Loss : 0.00105 - Train R2 score : 0.9028
# R2 Score Validation test set: [0.8425008]
# - Epoch : 261 - Loss : 0.00102 - Train R2 score : 0.9133
# R2 Score Validation test set: [0.8345684]
# - Epoch : 262 - Loss : 0.00101 - Train R2 score : 0.8639
# R2 Score Validation test set: [0.84307164]
# - Epoch : 263 - Loss : 0.00103 - Train R2 score : 0.9247
# R2 Score Validation test set: [0.8452034]
# - Epoch : 264 - Loss : 0.00097 - Train R2 score : 0.9065
# R2 Score Validation test set: [0.840925]
# - Epoch : 265 - Loss : 0.00100 - Train R2 score : 0.9085
# R2 Score Validation test set: [0.84007895]
# - Epoch : 266 - Loss : 0.00103 - Train R2 score : 0.8673
# R2 Score Validation test set: [0.8418977]
# - Epoch : 267 - Loss : 0.00099 - Train R2 score : 0.8981
# R2 Score Validation test set: [0.83967644]
# - Epoch : 268 - Loss : 0.00099 - Train R2 score : 0.8098
# R2 Score Validation test set: [0.8385974]
# - Epoch : 269 - Loss : 0.00104 - Train R2 score : 0.8719
# R2 Score Validation test set: [0.8408905]
# - Epoch : 270 - Loss : 0.00104 - Train R2 score : 0.8225
# R2 Score Validation test set: [0.84643704]
# - Epoch : 271 - Loss : 0.00100 - Train R2 score : 0.8613
# R2 Score Validation test set: [0.8460007]
# - Epoch : 272 - Loss : 0.00103 - Train R2 score : 0.8459
# R2 Score Validation test set: [0.849763]
# - Epoch : 273 - Loss : 0.00108 - Train R2 score : 0.8720
# R2 Score Validation test set: [0.83426917]
# - Epoch : 274 - Loss : 0.00101 - Train R2 score : 0.9322
# R2 Score Validation test set: [0.8496226]
# - Epoch : 275 - Loss : 0.00095 - Train R2 score : 0.9048
# R2 Score Validation test set: [0.8262528]
# - Epoch : 276 - Loss : 0.00105 - Train R2 score : 0.9263
# R2 Score Validation test set: [0.8420225]
# - Epoch : 277 - Loss : 0.00097 - Train R2 score : 0.8893
# R2 Score Validation test set: [0.830358]
# - Epoch : 278 - Loss : 0.00102 - Train R2 score : 0.9019
# R2 Score Validation test set: [0.83622223]
# - Epoch : 279 - Loss : 0.00097 - Train R2 score : 0.9181
# R2 Score Validation test set: [0.8454146]
# - Epoch : 280 - Loss : 0.00093 - Train R2 score : 0.9103
# R2 Score Validation test set: [0.8418271]
# - Epoch : 281 - Loss : 0.00097 - Train R2 score : 0.9166
# R2 Score Validation test set: [0.84387565]
# - Epoch : 282 - Loss : 0.00094 - Train R2 score : 0.9118
# R2 Score Validation test set: [0.8395331]
# - Epoch : 283 - Loss : 0.00094 - Train R2 score : 0.8915
# R2 Score Validation test set: [0.84797925]
# - Epoch : 284 - Loss : 0.00098 - Train R2 score : 0.8998
# R2 Score Validation test set: [0.8393865]
# - Epoch : 285 - Loss : 0.00098 - Train R2 score : 0.8588
# R2 Score Validation test set: [0.8497266]
# - Epoch : 286 - Loss : 0.00097 - Train R2 score : 0.8782
# R2 Score Validation test set: [0.8510112]
# Saving Model of score: [0.8510112] 0.8781972877335432
# - Epoch : 287 - Loss : 0.00096 - Train R2 score : 0.8079
# R2 Score Validation test set: [0.8468732]
# - Epoch : 288 - Loss : 0.00099 - Train R2 score : 0.9059
# R2 Score Validation test set: [0.8380633]
# - Epoch : 289 - Loss : 0.00094 - Train R2 score : 0.9159
# R2 Score Validation test set: [0.8357898]
# - Epoch : 290 - Loss : 0.00096 - Train R2 score : 0.9024
# R2 Score Validation test set: [0.8498315]
# - Epoch : 291 - Loss : 0.00094 - Train R2 score : 0.8910
# R2 Score Validation test set: [0.8466449]
# - Epoch : 292 - Loss : 0.00090 - Train R2 score : 0.8894
# R2 Score Validation test set: [0.8427138]
# - Epoch : 293 - Loss : 0.00096 - Train R2 score : 0.8532
# R2 Score Validation test set: [0.8413884]
# - Epoch : 294 - Loss : 0.00093 - Train R2 score : 0.8665
# R2 Score Validation test set: [0.84427214]
# - Epoch : 295 - Loss : 0.00091 - Train R2 score : 0.8606
# R2 Score Validation test set: [0.8376665]
# - Epoch : 296 - Loss : 0.00088 - Train R2 score : 0.8913
# R2 Score Validation test set: [0.8407428]
# - Epoch : 297 - Loss : 0.00098 - Train R2 score : 0.8852
# R2 Score Validation test set: [0.8473393]
# - Epoch : 298 - Loss : 0.00091 - Train R2 score : 0.9280
# R2 Score Validation test set: [0.84717417]
# - Epoch : 299 - Loss : 0.00099 - Train R2 score : 0.9260
# R2 Score Validation test set: [0.8400977]
# - Epoch : 300 - Loss : 0.00095 - Train R2 score : 0.9140
# R2 Score Validation test set: [0.8470158]
# - Epoch : 301 - Loss : 0.00092 - Train R2 score : 0.8876
# R2 Score Validation test set: [0.8546306]
# Saving Model of score: [0.8546306] 0.8876222156261613
# - Epoch : 302 - Loss : 0.00094 - Train R2 score : 0.8651
# R2 Score Validation test set: [0.8476434]
# - Epoch : 303 - Loss : 0.00094 - Train R2 score : 0.8706
# R2 Score Validation test set: [0.8361936]
# - Epoch : 304 - Loss : 0.00091 - Train R2 score : 0.8934
# R2 Score Validation test set: [0.84459555]
# - Epoch : 305 - Loss : 0.00092 - Train R2 score : 0.9327
# R2 Score Validation test set: [0.842911]
# - Epoch : 306 - Loss : 0.00090 - Train R2 score : 0.9235
# R2 Score Validation test set: [0.8512322]
# - Epoch : 307 - Loss : 0.00088 - Train R2 score : 0.8938
# R2 Score Validation test set: [0.8403013]
# - Epoch : 308 - Loss : 0.00092 - Train R2 score : 0.8254
# R2 Score Validation test set: [0.84842277]
# - Epoch : 309 - Loss : 0.00090 - Train R2 score : 0.9050
# R2 Score Validation test set: [0.8399439]
# - Epoch : 310 - Loss : 0.00093 - Train R2 score : 0.9123
# R2 Score Validation test set: [0.8436586]
# - Epoch : 311 - Loss : 0.00097 - Train R2 score : 0.8855
# R2 Score Validation test set: [0.83896124]
# - Epoch : 312 - Loss : 0.00091 - Train R2 score : 0.8504
# R2 Score Validation test set: [0.8444405]
# - Epoch : 313 - Loss : 0.00090 - Train R2 score : 0.8969
# R2 Score Validation test set: [0.8502825]
# - Epoch : 314 - Loss : 0.00090 - Train R2 score : 0.7925
# R2 Score Validation test set: [0.8491506]
# - Epoch : 315 - Loss : 0.00086 - Train R2 score : 0.9256
# R2 Score Validation test set: [0.835514]
# - Epoch : 316 - Loss : 0.00089 - Train R2 score : 0.8709
# R2 Score Validation test set: [0.85585225]
# Saving Model of score: [0.85585225] 0.8709476275380293
# - Epoch : 317 - Loss : 0.00088 - Train R2 score : 0.8773
# R2 Score Validation test set: [0.849817]
# - Epoch : 318 - Loss : 0.00088 - Train R2 score : 0.9252
# R2 Score Validation test set: [0.84250116]
# - Epoch : 319 - Loss : 0.00090 - Train R2 score : 0.8985
# R2 Score Validation test set: [0.82918966]
# - Epoch : 320 - Loss : 0.00088 - Train R2 score : 0.8864
# R2 Score Validation test set: [0.8388498]
# - Epoch : 321 - Loss : 0.00091 - Train R2 score : 0.9235
# R2 Score Validation test set: [0.8489911]
# - Epoch : 322 - Loss : 0.00092 - Train R2 score : 0.9147
# R2 Score Validation test set: [0.8479911]
# - Epoch : 323 - Loss : 0.00091 - Train R2 score : 0.8396
# R2 Score Validation test set: [0.8522322]
# - Epoch : 324 - Loss : 0.00090 - Train R2 score : 0.8975
# R2 Score Validation test set: [0.84050494]
# - Epoch : 325 - Loss : 0.00091 - Train R2 score : 0.9048
# R2 Score Validation test set: [0.83545136]
# - Epoch : 326 - Loss : 0.00090 - Train R2 score : 0.9113
# R2 Score Validation test set: [0.8406495]
# - Epoch : 327 - Loss : 0.00085 - Train R2 score : 0.8960
# R2 Score Validation test set: [0.8417877]
# - Epoch : 328 - Loss : 0.00084 - Train R2 score : 0.8849
# R2 Score Validation test set: [0.8395063]
# - Epoch : 329 - Loss : 0.00086 - Train R2 score : 0.8887
# R2 Score Validation test set: [0.83475894]
# - Epoch : 330 - Loss : 0.00088 - Train R2 score : 0.8816
# R2 Score Validation test set: [0.84652644]
# - Epoch : 331 - Loss : 0.00082 - Train R2 score : 0.8623
# R2 Score Validation test set: [0.8416834]
# - Epoch : 332 - Loss : 0.00087 - Train R2 score : 0.9200
# R2 Score Validation test set: [0.8464571]
# - Epoch : 333 - Loss : 0.00086 - Train R2 score : 0.8524
# R2 Score Validation test set: [0.84364116]
# - Epoch : 334 - Loss : 0.00089 - Train R2 score : 0.8734
# R2 Score Validation test set: [0.84348303]
# - Epoch : 335 - Loss : 0.00091 - Train R2 score : 0.8771
# R2 Score Validation test set: [0.8426902]
# - Epoch : 336 - Loss : 0.00084 - Train R2 score : 0.9376
# R2 Score Validation test set: [0.8427883]
# - Epoch : 337 - Loss : 0.00088 - Train R2 score : 0.8616
# R2 Score Validation test set: [0.84649074]
# - Epoch : 338 - Loss : 0.00084 - Train R2 score : 0.8207
# R2 Score Validation test set: [0.8432667]
# - Epoch : 339 - Loss : 0.00092 - Train R2 score : 0.9319
# R2 Score Validation test set: [0.847684]
# - Epoch : 340 - Loss : 0.00089 - Train R2 score : 0.9198
# R2 Score Validation test set: [0.8471433]
# - Epoch : 341 - Loss : 0.00090 - Train R2 score : 0.8548
# R2 Score Validation test set: [0.8411641]
# - Epoch : 342 - Loss : 0.00086 - Train R2 score : 0.9070
# R2 Score Validation test set: [0.84077597]
# - Epoch : 343 - Loss : 0.00088 - Train R2 score : 0.8956
# R2 Score Validation test set: [0.849851]
# - Epoch : 344 - Loss : 0.00086 - Train R2 score : 0.8934
# R2 Score Validation test set: [0.84832394]
# - Epoch : 345 - Loss : 0.00084 - Train R2 score : 0.8951
# R2 Score Validation test set: [0.8416578]
# - Epoch : 346 - Loss : 0.00085 - Train R2 score : 0.8055
# R2 Score Validation test set: [0.85233533]
# - Epoch : 347 - Loss : 0.00083 - Train R2 score : 0.9311
# R2 Score Validation test set: [0.848952]
# - Epoch : 348 - Loss : 0.00089 - Train R2 score : 0.9246
# R2 Score Validation test set: [0.8559029]
# Saving Model of score: [0.8559029] 0.9245526657690384
# - Epoch : 349 - Loss : 0.00082 - Train R2 score : 0.9197
# R2 Score Validation test set: [0.8496177]
# - Epoch : 350 - Loss : 0.00089 - Train R2 score : 0.9103
# R2 Score Validation test set: [0.83409816]
# - Epoch : 351 - Loss : 0.00083 - Train R2 score : 0.8975
# R2 Score Validation test set: [0.84162825]
# - Epoch : 352 - Loss : 0.00084 - Train R2 score : 0.9052
# R2 Score Validation test set: [0.83846366]
# - Epoch : 353 - Loss : 0.00086 - Train R2 score : 0.9110
# R2 Score Validation test set: [0.8356636]
# - Epoch : 354 - Loss : 0.00085 - Train R2 score : 0.9201
# R2 Score Validation test set: [0.85350883]
# - Epoch : 355 - Loss : 0.00084 - Train R2 score : 0.9116
# R2 Score Validation test set: [0.8380773]
# - Epoch : 356 - Loss : 0.00080 - Train R2 score : 0.9276
# R2 Score Validation test set: [0.8400278]
# - Epoch : 357 - Loss : 0.00084 - Train R2 score : 0.8905
# R2 Score Validation test set: [0.8451725]
# - Epoch : 358 - Loss : 0.00085 - Train R2 score : 0.9440
# R2 Score Validation test set: [0.8363748]
# - Epoch : 359 - Loss : 0.00081 - Train R2 score : 0.9334
# R2 Score Validation test set: [0.8416556]
# - Epoch : 360 - Loss : 0.00080 - Train R2 score : 0.9205
# R2 Score Validation test set: [0.850783]
# - Epoch : 361 - Loss : 0.00083 - Train R2 score : 0.9362
# R2 Score Validation test set: [0.8514849]
# - Epoch : 362 - Loss : 0.00083 - Train R2 score : 0.8555
# R2 Score Validation test set: [0.8406056]
# - Epoch : 363 - Loss : 0.00082 - Train R2 score : 0.8796
# R2 Score Validation test set: [0.84438705]
# - Epoch : 364 - Loss : 0.00085 - Train R2 score : 0.8767
# R2 Score Validation test set: [0.84776986]
# - Epoch : 365 - Loss : 0.00082 - Train R2 score : 0.9127
# R2 Score Validation test set: [0.84730756]
# - Epoch : 366 - Loss : 0.00083 - Train R2 score : 0.8937
# R2 Score Validation test set: [0.84350026]
# - Epoch : 367 - Loss : 0.00083 - Train R2 score : 0.8416
# R2 Score Validation test set: [0.8489734]
# - Epoch : 368 - Loss : 0.00087 - Train R2 score : 0.8667
# R2 Score Validation test set: [0.8373602]
# - Epoch : 369 - Loss : 0.00086 - Train R2 score : 0.9435
# R2 Score Validation test set: [0.84488547]
# - Epoch : 370 - Loss : 0.00080 - Train R2 score : 0.9242
# R2 Score Validation test set: [0.8372714]
# - Epoch : 371 - Loss : 0.00083 - Train R2 score : 0.9029
# R2 Score Validation test set: [0.8412549]
# - Epoch : 372 - Loss : 0.00080 - Train R2 score : 0.9194
# R2 Score Validation test set: [0.83625656]
# - Epoch : 373 - Loss : 0.00082 - Train R2 score : 0.8792
# R2 Score Validation test set: [0.8427174]
# - Epoch : 374 - Loss : 0.00082 - Train R2 score : 0.8628
# R2 Score Validation test set: [0.85828817]
# Saving Model of score: [0.85828817] 0.8627887113194292
# - Epoch : 375 - Loss : 0.00083 - Train R2 score : 0.9447
# R2 Score Validation test set: [0.8460069]
# - Epoch : 376 - Loss : 0.00081 - Train R2 score : 0.9352
# R2 Score Validation test set: [0.846401]
# - Epoch : 377 - Loss : 0.00078 - Train R2 score : 0.9289
# R2 Score Validation test set: [0.8481735]
# - Epoch : 378 - Loss : 0.00077 - Train R2 score : 0.8216
# R2 Score Validation test set: [0.84966815]
# - Epoch : 379 - Loss : 0.00082 - Train R2 score : 0.8485
# R2 Score Validation test set: [0.843928]
# - Epoch : 380 - Loss : 0.00079 - Train R2 score : 0.8300
# R2 Score Validation test set: [0.8378964]
# - Epoch : 381 - Loss : 0.00076 - Train R2 score : 0.8269
# R2 Score Validation test set: [0.8451871]
# - Epoch : 382 - Loss : 0.00080 - Train R2 score : 0.8615
# R2 Score Validation test set: [0.83970946]
# - Epoch : 383 - Loss : 0.00080 - Train R2 score : 0.9334
# R2 Score Validation test set: [0.8503878]
# - Epoch : 384 - Loss : 0.00084 - Train R2 score : 0.8640
# R2 Score Validation test set: [0.84350854]
# - Epoch : 385 - Loss : 0.00078 - Train R2 score : 0.9460
# R2 Score Validation test set: [0.8509596]
# - Epoch : 386 - Loss : 0.00081 - Train R2 score : 0.9349
# R2 Score Validation test set: [0.8483834]
# - Epoch : 387 - Loss : 0.00082 - Train R2 score : 0.9122
# R2 Score Validation test set: [0.84029865]
# - Epoch : 388 - Loss : 0.00082 - Train R2 score : 0.9257
# R2 Score Validation test set: [0.85871965]
# Saving Model of score: [0.85871965] 0.9257482842421395
# - Epoch : 389 - Loss : 0.00082 - Train R2 score : 0.9235
# R2 Score Validation test set: [0.84766936]
# - Epoch : 390 - Loss : 0.00081 - Train R2 score : 0.8970
# R2 Score Validation test set: [0.84373564]
# - Epoch : 391 - Loss : 0.00078 - Train R2 score : 0.9322
# R2 Score Validation test set: [0.84944063]
# - Epoch : 392 - Loss : 0.00083 - Train R2 score : 0.8219
# R2 Score Validation test set: [0.84665686]
# - Epoch : 393 - Loss : 0.00084 - Train R2 score : 0.8912
# R2 Score Validation test set: [0.84673774]
# - Epoch : 394 - Loss : 0.00084 - Train R2 score : 0.8488
# R2 Score Validation test set: [0.83754295]
# - Epoch : 395 - Loss : 0.00079 - Train R2 score : 0.8773
# R2 Score Validation test set: [0.84753484]
# - Epoch : 396 - Loss : 0.00079 - Train R2 score : 0.9030
# R2 Score Validation test set: [0.84824264]
# - Epoch : 397 - Loss : 0.00079 - Train R2 score : 0.8999
# R2 Score Validation test set: [0.84315014]
# - Epoch : 398 - Loss : 0.00077 - Train R2 score : 0.9015
# R2 Score Validation test set: [0.84962106]
# - Epoch : 399 - Loss : 0.00079 - Train R2 score : 0.9362
# R2 Score Validation test set: [0.8475904]
# - Epoch : 400 - Loss : 0.00083 - Train R2 score : 0.8209
# R2 Score Validation test set: [0.8497685]
# - Epoch : 401 - Loss : 0.00079 - Train R2 score : 0.9399
# R2 Score Validation test set: [0.84768826]
# - Epoch : 402 - Loss : 0.00085 - Train R2 score : 0.9179
# R2 Score Validation test set: [0.84201264]
# - Epoch : 403 - Loss : 0.00076 - Train R2 score : 0.9358
# R2 Score Validation test set: [0.8457744]
# - Epoch : 404 - Loss : 0.00082 - Train R2 score : 0.9188
# R2 Score Validation test set: [0.84341836]
# - Epoch : 405 - Loss : 0.00076 - Train R2 score : 0.8699
# R2 Score Validation test set: [0.85325974]
# - Epoch : 406 - Loss : 0.00081 - Train R2 score : 0.8612
# R2 Score Validation test set: [0.84092313]
# - Epoch : 407 - Loss : 0.00080 - Train R2 score : 0.8979
# R2 Score Validation test set: [0.84541327]
# - Epoch : 408 - Loss : 0.00080 - Train R2 score : 0.9178
# R2 Score Validation test set: [0.84176695]
# - Epoch : 409 - Loss : 0.00084 - Train R2 score : 0.8405
# R2 Score Validation test set: [0.84915125]
# - Epoch : 410 - Loss : 0.00080 - Train R2 score : 0.9031
# R2 Score Validation test set: [0.8456967]
# - Epoch : 411 - Loss : 0.00084 - Train R2 score : 0.9246
# R2 Score Validation test set: [0.8550441]
# - Epoch : 412 - Loss : 0.00081 - Train R2 score : 0.8759
# R2 Score Validation test set: [0.85416436]
# - Epoch : 413 - Loss : 0.00078 - Train R2 score : 0.8997
# R2 Score Validation test set: [0.8595457]
# Saving Model of score: [0.8595457] 0.8996994398897489
# - Epoch : 414 - Loss : 0.00080 - Train R2 score : 0.9552
# R2 Score Validation test set: [0.8368434]
# - Epoch : 415 - Loss : 0.00079 - Train R2 score : 0.9295
# R2 Score Validation test set: [0.84808314]
# - Epoch : 416 - Loss : 0.00081 - Train R2 score : 0.8867
# R2 Score Validation test set: [0.8483869]
# - Epoch : 417 - Loss : 0.00078 - Train R2 score : 0.8437
# R2 Score Validation test set: [0.8571045]
# - Epoch : 418 - Loss : 0.00082 - Train R2 score : 0.8726
# R2 Score Validation test set: [0.865201]
# Saving Model of score: [0.865201] 0.8725598605699774
# - Epoch : 419 - Loss : 0.00082 - Train R2 score : 0.8909
# R2 Score Validation test set: [0.8456883]
# - Epoch : 420 - Loss : 0.00081 - Train R2 score : 0.9386
# R2 Score Validation test set: [0.8508252]
# - Epoch : 421 - Loss : 0.00083 - Train R2 score : 0.9233
# R2 Score Validation test set: [0.840746]
# - Epoch : 422 - Loss : 0.00079 - Train R2 score : 0.9236
# R2 Score Validation test set: [0.8433372]
# - Epoch : 423 - Loss : 0.00079 - Train R2 score : 0.9315
# R2 Score Validation test set: [0.8421209]
# - Epoch : 424 - Loss : 0.00075 - Train R2 score : 0.8913
# R2 Score Validation test set: [0.84952706]
# - Epoch : 425 - Loss : 0.00081 - Train R2 score : 0.8498
# R2 Score Validation test set: [0.85240835]
# - Epoch : 426 - Loss : 0.00079 - Train R2 score : 0.9313
# R2 Score Validation test set: [0.86432064]
# - Epoch : 427 - Loss : 0.00079 - Train R2 score : 0.8878
# R2 Score Validation test set: [0.8518473]
# - Epoch : 428 - Loss : 0.00077 - Train R2 score : 0.9041
# R2 Score Validation test set: [0.85165685]
# - Epoch : 429 - Loss : 0.00077 - Train R2 score : 0.9211
# R2 Score Validation test set: [0.8552988]
# - Epoch : 430 - Loss : 0.00076 - Train R2 score : 0.8461
# R2 Score Validation test set: [0.84456587]
# - Epoch : 431 - Loss : 0.00080 - Train R2 score : 0.8789
# R2 Score Validation test set: [0.8550831]
# - Epoch : 432 - Loss : 0.00077 - Train R2 score : 0.9109
# R2 Score Validation test set: [0.84196854]
# - Epoch : 433 - Loss : 0.00076 - Train R2 score : 0.9388
# R2 Score Validation test set: [0.8474622]
# - Epoch : 434 - Loss : 0.00078 - Train R2 score : 0.9271
# R2 Score Validation test set: [0.8431397]
# - Epoch : 435 - Loss : 0.00082 - Train R2 score : 0.8984
# R2 Score Validation test set: [0.84531915]
# - Epoch : 436 - Loss : 0.00072 - Train R2 score : 0.9283
# R2 Score Validation test set: [0.84567165]
# - Epoch : 437 - Loss : 0.00076 - Train R2 score : 0.8665
# R2 Score Validation test set: [0.84682363]
# - Epoch : 438 - Loss : 0.00077 - Train R2 score : 0.9147
# R2 Score Validation test set: [0.8549363]
# - Epoch : 439 - Loss : 0.00079 - Train R2 score : 0.9172
# R2 Score Validation test set: [0.84667426]
# - Epoch : 440 - Loss : 0.00079 - Train R2 score : 0.9259
# R2 Score Validation test set: [0.85250807]
# - Epoch : 441 - Loss : 0.00077 - Train R2 score : 0.8732
# R2 Score Validation test set: [0.8480032]
# - Epoch : 442 - Loss : 0.00077 - Train R2 score : 0.9332
# R2 Score Validation test set: [0.8420257]
# - Epoch : 443 - Loss : 0.00076 - Train R2 score : 0.8790
# R2 Score Validation test set: [0.85379344]
# - Epoch : 444 - Loss : 0.00076 - Train R2 score : 0.8551
# R2 Score Validation test set: [0.8452436]
# - Epoch : 445 - Loss : 0.00079 - Train R2 score : 0.8788
# R2 Score Validation test set: [0.8627788]
# - Epoch : 446 - Loss : 0.00076 - Train R2 score : 0.8972
# R2 Score Validation test set: [0.85243833]
# - Epoch : 447 - Loss : 0.00077 - Train R2 score : 0.9498
# R2 Score Validation test set: [0.85083145]
# - Epoch : 448 - Loss : 0.00077 - Train R2 score : 0.8938
# R2 Score Validation test set: [0.84500086]
# - Epoch : 449 - Loss : 0.00077 - Train R2 score : 0.9515
# R2 Score Validation test set: [0.84746724]
# - Epoch : 450 - Loss : 0.00085 - Train R2 score : 0.8017
# R2 Score Validation test set: [0.8339515]
# - Epoch : 451 - Loss : 0.00075 - Train R2 score : 0.8571
# R2 Score Validation test set: [0.8541218]
# - Epoch : 452 - Loss : 0.00084 - Train R2 score : 0.8829
# R2 Score Validation test set: [0.8534486]
# - Epoch : 453 - Loss : 0.00078 - Train R2 score : 0.8341
# R2 Score Validation test set: [0.8429103]
# - Epoch : 454 - Loss : 0.00078 - Train R2 score : 0.8663
# R2 Score Validation test set: [0.85480195]
# - Epoch : 455 - Loss : 0.00077 - Train R2 score : 0.8904
# R2 Score Validation test set: [0.84777623]
# - Epoch : 456 - Loss : 0.00075 - Train R2 score : 0.9354
# R2 Score Validation test set: [0.84282327]
# - Epoch : 457 - Loss : 0.00076 - Train R2 score : 0.9198
# R2 Score Validation test set: [0.85033774]
# - Epoch : 458 - Loss : 0.00075 - Train R2 score : 0.9238
# R2 Score Validation test set: [0.8498657]
# - Epoch : 459 - Loss : 0.00076 - Train R2 score : 0.9287
# R2 Score Validation test set: [0.82834685]
# - Epoch : 460 - Loss : 0.00079 - Train R2 score : 0.9118
# R2 Score Validation test set: [0.8530966]
# - Epoch : 461 - Loss : 0.00076 - Train R2 score : 0.9311
# R2 Score Validation test set: [0.85198164]
# - Epoch : 462 - Loss : 0.00076 - Train R2 score : 0.8612
# R2 Score Validation test set: [0.84943324]
# - Epoch : 463 - Loss : 0.00077 - Train R2 score : 0.7861
# R2 Score Validation test set: [0.8519548]
# - Epoch : 464 - Loss : 0.00075 - Train R2 score : 0.9048
# R2 Score Validation test set: [0.8445251]
# - Epoch : 465 - Loss : 0.00074 - Train R2 score : 0.9033
# R2 Score Validation test set: [0.85507035]
# - Epoch : 466 - Loss : 0.00082 - Train R2 score : 0.8333
# R2 Score Validation test set: [0.84646213]
# - Epoch : 467 - Loss : 0.00076 - Train R2 score : 0.8873
# R2 Score Validation test set: [0.85877305]
# - Epoch : 468 - Loss : 0.00078 - Train R2 score : 0.8640
# R2 Score Validation test set: [0.8621251]
# - Epoch : 469 - Loss : 0.00073 - Train R2 score : 0.9243
# R2 Score Validation test set: [0.84262586]
# - Epoch : 470 - Loss : 0.00075 - Train R2 score : 0.9414
# R2 Score Validation test set: [0.84231794]
# - Epoch : 471 - Loss : 0.00076 - Train R2 score : 0.8651
# R2 Score Validation test set: [0.85220855]
# - Epoch : 472 - Loss : 0.00077 - Train R2 score : 0.9382
# R2 Score Validation test set: [0.8462193]
# - Epoch : 473 - Loss : 0.00074 - Train R2 score : 0.9346
# R2 Score Validation test set: [0.8446582]
# - Epoch : 474 - Loss : 0.00078 - Train R2 score : 0.8646
# R2 Score Validation test set: [0.8438318]
# - Epoch : 475 - Loss : 0.00076 - Train R2 score : 0.9523
# R2 Score Validation test set: [0.8537092]
# - Epoch : 476 - Loss : 0.00074 - Train R2 score : 0.7628
# R2 Score Validation test set: [0.85477304]
# - Epoch : 477 - Loss : 0.00073 - Train R2 score : 0.8941
# R2 Score Validation test set: [0.84637725]
# - Epoch : 478 - Loss : 0.00077 - Train R2 score : 0.9137
# R2 Score Validation test set: [0.8423252]
# - Epoch : 479 - Loss : 0.00071 - Train R2 score : 0.9279
# R2 Score Validation test set: [0.85011226]
# - Epoch : 480 - Loss : 0.00078 - Train R2 score : 0.9213
# R2 Score Validation test set: [0.84027696]
# - Epoch : 481 - Loss : 0.00076 - Train R2 score : 0.9182
# R2 Score Validation test set: [0.8512856]
# - Epoch : 482 - Loss : 0.00079 - Train R2 score : 0.9111
# R2 Score Validation test set: [0.846218]
# - Epoch : 483 - Loss : 0.00078 - Train R2 score : 0.8707
# R2 Score Validation test set: [0.8451765]
# - Epoch : 484 - Loss : 0.00072 - Train R2 score : 0.9331
# R2 Score Validation test set: [0.851831]
# - Epoch : 485 - Loss : 0.00074 - Train R2 score : 0.9273
# R2 Score Validation test set: [0.8501164]
# - Epoch : 486 - Loss : 0.00074 - Train R2 score : 0.9270
# R2 Score Validation test set: [0.85041636]
# - Epoch : 487 - Loss : 0.00078 - Train R2 score : 0.8931
# R2 Score Validation test set: [0.84880805]
# - Epoch : 488 - Loss : 0.00075 - Train R2 score : 0.9412
# R2 Score Validation test set: [0.8427037]
# - Epoch : 489 - Loss : 0.00078 - Train R2 score : 0.9426
# R2 Score Validation test set: [0.8507358]
# - Epoch : 490 - Loss : 0.00075 - Train R2 score : 0.9154
# R2 Score Validation test set: [0.84551585]
# - Epoch : 491 - Loss : 0.00074 - Train R2 score : 0.9167
# R2 Score Validation test set: [0.85753304]
# - Epoch : 492 - Loss : 0.00078 - Train R2 score : 0.9543
# R2 Score Validation test set: [0.8551034]
# - Epoch : 493 - Loss : 0.00075 - Train R2 score : 0.8621
# R2 Score Validation test set: [0.8507047]
# - Epoch : 494 - Loss : 0.00075 - Train R2 score : 0.8384
# R2 Score Validation test set: [0.84996265]
# - Epoch : 495 - Loss : 0.00072 - Train R2 score : 0.8926
# R2 Score Validation test set: [0.8499079]
# - Epoch : 496 - Loss : 0.00073 - Train R2 score : 0.9140
# R2 Score Validation test set: [0.8577992]
# - Epoch : 497 - Loss : 0.00077 - Train R2 score : 0.8232
# R2 Score Validation test set: [0.8536864]
# - Epoch : 498 - Loss : 0.00078 - Train R2 score : 0.8507
# R2 Score Validation test set: [0.85190433]
# - Epoch : 499 - Loss : 0.00072 - Train R2 score : 0.9334
# R2 Score Validation test set: [0.85274976]
# - Epoch : 500 - Loss : 0.00074 - Train R2 score : 0.9151
# R2 Score Validation test set: [0.8465222]

# %%
import gc

torch.cuda.empty_cache()
gc.collect()
# Out:
# 9

# %%
model=torch.load('ECC_model_Tranfer.pt')

# %%
device=torch.device('cpu')
model=model.to(device)

# %%
import matplotlib.pyplot as plt
test_score,model,y_score,y_test=test(model, device,test_loader, args)
y_test=y_test.reshape(y_test.shape[0],1)
output_test=[]
target_test=[]
for i in range(y_score.shape[0]):
    output_test.append(y_score[i][0])
    target_test.append(y_test[i][0])
#print(output_test)
# y_score is in the form of torch tensor. So not converted to numpy properly
x=np.array([i for i in range(len(y_score))])
#print(len(x),y_score[0])
#print(y_score,x.shape)
#target=list(y_test[0])

#plt.ylim(0,0.3)
plt.title('Residual plot on Test Set')
plt.scatter(x,y=(np.array(output_test)-np.array(target_test)),color='red',label='Predicted',s=20)
plt.ylabel('Residual Values')
plt.xlabel('Data Points')
plt.show()
plt.scatter(x,y=target_test,color='blue',label='Actual Values',s=20)
plt.show()

print(y_test.shape,y_score.shape)
plt.scatter(target_test,output_test,s=10)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.show()
# Out:
# R2 Score Validation test set: [0.8529253]
# (686, 1) (686, 1)

# %%
# converting data to actual boiling points
#print(y_score[0][0])
for i in range(len(output_test)):
    # predicted
    output_test[i]=output_test[i]*(max_val-min_val)+min_val
    output_test[i]=output_test[i]*std+mean

    # Actual
    target_test[i]=target_test[i]*(max_val-min_val)+min_val
    target_test[i]=target_test[i]*std+mean

# %%
plt.scatter(target_test,output_test,s=10)
plt.plot([0,1000],[0,1000],color='black')
plt.plot([0,900],[0,1000],color='black',linestyle='dashed',label='10 Percent error Line') # +10 % error
plt.plot([0,1000],[0,900],color='black',linestyle='dashed') # -10 % error
plt.xlabel("Actual Boiling Point Values")
plt.ylabel("Predicted Boiling Point Values")
plt.ylim(0,1000)
plt.xlim(0,1000)
plt.legend()
plt.title('Parity Plot on Test Set')
plt.text(500,100,s=f'R2 Score = {test_score}')
plt.show()

# %%
# Save test 
test_data= pd.DataFrame()
test_data['ECC Outliers removed Actual Boiling Point']=target_test
test_data['ECC Outliers removed Predicted Boiling Point']=output_test
test_data.to_csv('../data/Results/ECC_ Outliers_pytorch_Test_values.csv')

# %%
# Train set predictions save
train_loader_pred = DataLoader(train_X, batch_size=len(train_X), shuffle=False, drop_last=True)
len(train_X)
# Out:
# 6167

# %%
import gc

torch.cuda.empty_cache()
gc.collect()
# Out:
# 10837

# %%
import matplotlib.pyplot as plt
train_score,model,y_score,y_test=test(model, device,train_loader_pred, args)
y_test=y_test.reshape(y_test.shape[0],1)
output_test=[]
target_test=[]
for i in range(y_score.shape[0]):
    output_test.append(y_score[i][0])
    target_test.append(y_test[i][0])
print(len(output_test))
# y_score is in the form of torch tensor. So not converted to numpy properly
x=np.array([i for i in range(len(y_score))])
#print(len(x),y_score[0])
#print(y_score,x.shape)
#target=list(y_test[0])

#plt.ylim(0,0.3)
plt.title('Residual plot on Train Set')
plt.scatter(x,y=(np.array(output_test)-np.array(target_test)),color='red',label='Predicted',s=20)
plt.ylabel('Residual Values')
plt.xlabel('Data Points')
plt.show()
plt.scatter(x,y=target_test,color='blue',label='Actual Values',s=20)
plt.show()

#print(y_test.shape,y_score.shape)
plt.scatter(target_test,output_test,s=10)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.show()
# Out:
# R2 Score Validation test set: [0.9284204]
# 6167

# %%
# converting data to actual boiling points
#print(y_score[0][0])
for i in range(len(output_test)):
    # predicted
    output_test[i]=output_test[i]*(max_val-min_val)+min_val
    output_test[i]=output_test[i]*std+mean

    # Actual
    target_test[i]=target_test[i]*(max_val-min_val)+min_val
    target_test[i]=target_test[i]*std+mean

# %%
plt.scatter(output_test,target_test,s=10)
plt.plot([0,1000],[0,1000],color='black')
plt.plot([0,900],[0,1000],color='black',linestyle='dashed',label='10 percent error line') # +10 % error
plt.plot([0,1000],[0,900],color='black',linestyle='dashed') # -10 % error
plt.ylim(0,1000)
plt.xlim(0,1000)
plt.xlabel("Actual Boiling Point Values")
plt.ylabel("Predicted Boiling Point Values")
plt.text(500,100,s=f'R2 Score = {train_score}')
plt.legend()
plt.title('Parity Plot on Train Set')
plt.show()

# %%
# Save train
test_data= pd.DataFrame()
test_data['ECC Outliers removed Actual Boiling Point']=target_test
test_data['ECC Outliers removed Predicted Boiling Point']=output_test
test_data.to_csv('../data/Results/ECC_ Outliers_pytorch_Train_values.csv')
