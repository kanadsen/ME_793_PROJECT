# %%
# Imports all the required packages
import os
import argparse
import numpy as np
import os.path as osp
import pandas as pd
from sklearn.model_selection import train_test_split
from torch_geometric.data import (InMemoryDataset, download_url, extract_zip,Data)

import torch
#from torcheval.metrics import R2Score # To be implemented
import torch.nn as nn
import torch.nn.functional as F
from rdkit.Chem import DataStructs
from torch_geometric.loader import DataLoader

import torch.nn.functional as F
from torch.nn import Linear
from torch.nn import BatchNorm1d
import torch.optim as optim
from torch_geometric.nn import GCNConv,GraphConv,NNConv
from torch_geometric.nn import global_add_pool,knn_graph

try:
    import rdkit
    from rdkit import Chem
    from rdkit.Chem import AllChem
    from rdkit import rdBase
    from rdkit.Chem.rdchem import HybridizationType
    from rdkit import RDConfig
    from rdkit.Chem import ChemicalFeatures
    from rdkit.Chem.rdchem import BondType as BT
    from rdkit.Chem import Draw
    rdBase.DisableLog('rdApp.error')
except ImportError:
    print("rdkit = None")

# %%
# Model definition used for regression

class GCNlayer(nn.Module):
    
    def __init__(self, n_features, conv_dims, concat_dim, dropout):
        super(GCNlayer, self).__init__()
        self.n_features = n_features
        self.conv_dims = conv_dims
        self.concat_dim =  concat_dim
        self.dropout = dropout
        
        self.convs = nn.ModuleList()
        self.bns = nn.ModuleList()
        self.gru=nn.ModuleList()
        #args.conv_dims=[args.n_features,128,512,4092]
        self.lin0 = torch.nn.Linear(args.n_features, self.conv_dims[0]) # Changed from 128
        for i in range(len(self.conv_dims)-1):
            kk = nn.Sequential(Linear(6, self.conv_dims[i+1]), nn.ReLU(), Linear(self.conv_dims[i+1], self.conv_dims[i+1]*self.conv_dims[i+1]))
            conv = NNConv(self.conv_dims[i], self.conv_dims[i+1],kk,aggr='add')
            self.convs.append(conv)
            bn = BatchNorm1d(self.conv_dims[i+1])
            self.bns.append(bn)
            self.gru.append(nn.GRU(self.conv_dims[i+1], self.conv_dims[i+1])) # Changed
        self.conv_last = GraphConv(self.conv_dims[-1],self.conv_dims[-1])  # Last layer
        self.bn_last = BatchNorm1d(self.concat_dim)
        
    def forward(self, data):
        x, edge_index,edge_attr= data.x, data.edge_index,data.edge_attr # Changed . added edge_attr
        out = F.relu(self.lin0(x))
        h = out.unsqueeze(0)
        for i in range(len(self.convs)):
            m = F.relu(self.convs[i](out, edge_index,edge_attr)) # Changed . added edge_attr
            m = self.bns[i](m)
            out, h = self.gru[i](m.unsqueeze(0), h)  # Changed here. Added [i]
            out = out.squeeze(0)

        x = F.relu(self.conv_last(out, edge_index))# Changed . added edge_attr
        x = self.bn_last(x)
        x = global_add_pool(x,batch=data.batch)   #global_add_pool  cHANGED
        x = F.dropout(x, p=self.dropout, training=self.training)
        return x
    
class FClayer(nn.Module):
    
    def __init__(self, concat_dim, pred_dims, out_dim, dropout):
        super(FClayer, self).__init__()
        self.concat_dim = concat_dim
        self.pred_dims = pred_dims
        self.out_dim = out_dim
        self.dropout = dropout

        self.fcs = nn.ModuleList()
        self.bns = nn.ModuleList()
        # Linear layer has bias default=True
        for i in range(len(self.pred_dims)-1):
            fc = Linear(self.pred_dims[i], self.pred_dims[i+1])
            self.fcs.append(fc)
            bn = BatchNorm1d(self.pred_dims[i+1])
            self.bns.append(bn)
        self.fc_last = Linear(self.pred_dims[-1], self.out_dim)
    
    def forward(self, data):
        x = data
        for i in range(len(self.fcs)):
            x = F.relu(self.fcs[i](x))
            x = self.bns[i](x)
            x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.fc_last(x)
        return x

# Model definition  
class GCN_Model_reg(nn.Module):
    def __init__(self, args):
        super(GCN_Model_reg, self).__init__()
        
        # Convolutional Layer call
        self.conv = GCNlayer(args.n_features,args.conv_dims,args.concat_dim,args.dropout)

        # Fully connected layer call
        self.fc = FClayer(args.concat_dim,args.pred_dims,args.out_dim,args.dropout)
        
    def forward(self, data):
        x = self.conv(data) # Calling the convolutional layercpu
        x = self.fc(x) # Calling the Fully Connected Layer
        return x

# %%
# pytorch will be run on cpu
seed=200
paser = argparse.ArgumentParser()
args = paser.parse_args("")
np.random.seed(200)
torch.manual_seed(seed)
device=input("Enter cuda or cpu for device type")
device = torch.device(device)
#'cuda' if torch.cuda.is_available() else
device
# Out:
# device(type='cuda')

# %%
# Inputs required by the program
args.epoch = 400
args.lr = 0.0001
args.optim = 'Adam'
args.step_size = 25
args.gamma = 0.8
args.dropout = 0.1 # Tested for 0.2 but max r2 got 0.874. For 0.1 I got 0.897
args.n_features = 30  # Mass added else 29. Without atomic mass r2 0.899
args.concat_dim=128
args.conv_dims=[128,128,128] # Removed 1 layer
args.pred_dims=[128,512,128]
args.out_dim = 1

# %%
# encoding of all variables

def one_of_k_encoding(x, allowable_set):
    if x not in allowable_set:
        raise Exception("input {0} not in allowable set{1}:".format(x, allowable_set))
    return list(map(lambda s: x == s, allowable_set))

def one_of_k_encoding_unk(x, allowable_set):
    """Maps inputs not in the allowable set to the last element."""
    if x not in allowable_set:
        x = allowable_set[-1]
    return list(map(lambda s: x == s, allowable_set))
 
def get_intervals(l):
    """For list of lists, gets the cumulative products of the lengths"""
    intervals = len(l) * [0]
    # Initalize with 1
    intervals[0] = 1
    for k in range(1, len(l)):
        intervals[k] = (len(l[k]) + 1) * intervals[k - 1]
    return intervals

def safe_index(l, e):
    """Gets the index of e in l, providing an index of len(l) if not found"""
    try:
        return l.index(e)
    except:
        print("Add value to list of length {}".format(len(l)))
        return len(l)

# %%
# Atom features

possible_atom_list = ['H','C', 'O', 'F','N','Cl','P','S','Si','Br','I']  # Atomic symbol 11

aromatic=[0,1] # Aromatic 1
isring=[0,1]   # Ring 1
possible_numH_list = [0, 1, 2, 3, 4] # Total Number of bonded hydrogen atoms possible 5
num_bonds = [0, 1, 2, 3, 4, 5]  # Total Number of Hs a carbon can bond / Total number of bonds an atom make 6
possible_formal_charge_list = [-4,-3, -2, -1, 0, 1, 2, 3, 4]

# sp3d is removed because it doesnot vary according to the paper . Hybridization 4
possible_hybridization_list = [Chem.rdchem.HybridizationType.SP, Chem.rdchem.HybridizationType.SP2,Chem.rdchem.HybridizationType.SP3,Chem.rdchem.HybridizationType.SP3D2]

# storing all the features in a detailed list
reference_lists = [possible_atom_list, possible_numH_list,possible_formal_charge_list, num_bonds,aromatic,isring,possible_hybridization_list]

intervals = get_intervals(reference_lists)
print(intervals)
# Out:
# [1, 6, 60, 420, 1260, 3780, 18900]

# %% [markdown]
# - Total number of atom features used here is = 29

# %%
# Concatenate the entire feature list
def get_feature_list(atom):
    features = 5 * [0]
    features[0] = safe_index(possible_atom_list, atom.GetSymbol())
    features[1] = safe_index(possible_numH_list, atom.GetTotalNumHs())
    features[2] = safe_index(num_bonds, atom.GetImplicitValence())
    features[3] = safe_index(possible_formal_charge_list, atom.GetFormalCharge())    
    features[4] = safe_index(possible_hybridization_list, atom.GetHybridization())
    return features

# %%
def atom_features(atom,bool_id_feat=False,explicit_H=False):
    from rdkit import Chem
    results = np.array(one_of_k_encoding_unk(atom.GetSymbol(),possible_atom_list) + 
                           one_of_k_encoding_unk(atom.GetImplicitValence(), num_bonds) + 
                           [atom.GetFormalCharge()] + 
                           one_of_k_encoding_unk(atom.GetHybridization(), possible_hybridization_list) + 
                           [atom.GetIsAromatic()]+[atom.IsInRing()]+[atom.GetAtomicNum()])  # Atomic mass added  atom.GetAtomicNum() r2=0.907
    if not explicit_H:
        results = np.array(results.tolist() + one_of_k_encoding_unk(atom.GetTotalNumHs(),possible_numH_list))  # include neighbouring Hs
    return np.array(results)

# %%
# Bond Features

def bond_features(bond):
    from rdkit import Chem
    bt = bond.GetBondType()
    bond_feats = [bt == Chem.rdchem.BondType.SINGLE, bt == Chem.rdchem.BondType.DOUBLE,
                  bt == Chem.rdchem.BondType.TRIPLE, bt == Chem.rdchem.BondType.AROMATIC,
                  bond.GetIsConjugated(),bond.IsInRing()]
    
    # Include stereo bond features as it effects the boiling point
    #bond_feats = bond_feats + one_of_k_encoding_unk(str(bond.GetStereo()),["STEREONONE", "STEREOANY", "STEREOZ", "STEREOE"])
    return np.array(bond_feats)

# %% [markdown]
# - In the above bond features we have commented the stereo feature because we have seen that the smiles string has not been encoded to represent the information of the stereo state of the chemical formula.

# %%
# Create  atom pair of two connected molecules to pass messages

def get_bond_pair(mol):
    bonds = mol.GetBonds()
    res = [[],[]]
    for bond in bonds:
        res[0] += [bond.GetBeginAtomIdx(), bond.GetEndAtomIdx()]
        res[1] += [bond.GetEndAtomIdx(), bond.GetBeginAtomIdx()]
    return res

# create a graph data structure comprising of x=node_f, edge_index = bond pair info, 
# Here we are taking converted molecule from smiles as string
def mol2vec(mol):
    atoms = mol.GetAtoms()
    bonds = mol.GetBonds()
    node_f= [atom_features(atom) for atom in atoms]
    edge_index = get_bond_pair(mol)
    edge_attr = [bond_features(bond) for bond in bonds]

    for bond in bonds:
        edge_attr.append(bond_features(bond))
        
    # Graph data to be used
    # changes made in edge index format 
    data = Data(x=torch.tensor(node_f, dtype=torch.float),edge_index=torch.tensor(edge_index, dtype=torch.long),edge_attr=torch.tensor(edge_attr,dtype=torch.float))
    
    #print(data)
    return data,edge_attr,node_f

# %%
# Return mol info
def make_mol(df):
    mols = {}
    for i in range(df.shape[0]):
        mols[Chem.MolFromSmiles(df['Smiles'].iloc[i])] = df['Tm'].iloc[i]
    return mols

# %%
# Convert the dataset with X values and y values to be trained/tested
def make_vec(mols):
    X = []
    for m in mols.keys():
        if m is None:
            continue
        s,_,_=mol2vec(m) 
        X.append(s)
    for i, data in enumerate(X):
        y = list(mols.values())[i]
        data.y = torch.tensor([y], dtype=torch.float)
    return X

# %%
# Pca on graph data
#import umap
from sklearn.decomposition import PCA
def tsne_g(n,e):
    #print(e[0],e[1])
    model=PCA(n_components=20)
    # apply padding
    max_len_n = max(x.shape[0] for x in n)
    target_shape=np.array([0 for i in range(6)])
    for i in range(len(n)):
        c=max_len_n-n[i].shape[0]
        for j in range(c):
          n[i]=np.vstack((n[i], target_shape))
    #print(n)


    max_len_e = max(x.shape[0] for x in e)
    target_shape=np.array([0 for i in range(29)])
    for i in range(len(e)):
        c=max_len_n-e[i].shape[0]
        for j in range(c):
          e[i]=np.vstack((e[i], target_shape))
    #print(e)
    
    n=np.array(n)
    e=np.array(e)
    print(n.shape,e.shape)
    feature_matrix = np.concatenate((n,e), axis=2)

    # apply t-SNE
    #tsne = TSNE(n_components=5,perplexity=30)

    transformed_matrix = model.fit_transform(feature_matrix)

    print("Original feature matrix:")
    print(feature_matrix)
    print("\nTransformed feature matrix:")
    print(transformed_matrix)

# %%
def call_pca(mols):
    n=[]
    e=[]
    for m in mols.keys():
        _,i,j=mol2vec(m) 
        n.append(np.array(i))
        e.append(np.array(j))
    tsne_g(n,e)

# %% [markdown]
# ### Importing dataset

# %%
# Importing Dataset
dataset = pd.read_csv('../data/Tm_gc.csv')
dataset = pd.concat([dataset['Smiles'], dataset['Tm']], axis=1)
dataset
# Out:
#                                               Smiles      Tm
# 0                                 O=C(N)Nc1ccc(C)cc1  456.15
# 1       OCC(C(Oc1ccc(cc1)c2ccccc2)N3C=NC=N3)C(C)(C)C  391.15
# 2                      COC(=O)COc1nc(F)c(Cl)c(N)c1Cl  331.35
# 3                                 O=C(O)CNCP(=O)(O)O  533.15
# 4     O=N(=O)c1cc(ccc1C(=O)C2C(=O)CCCC2=O)S(=O)(=O)C  438.15
# ...                                              ...     ...
# 7044                CCC(C(=O)O)C1(O)CCC(CC1)c2ccccc2  430.15
# 7045                      OCC1CCC(O1)N2C=CC(=O)NC2=O  401.15
# 7046                  CC1CCC2(O)C(C)(C)C3CCC2(C)C1C3  329.15
# 7047                              CC1=CCC(CC1)C(=C)C  198.85
# 7048                              C1CC2C3CCC(C3)C2C1  350.15
#
# [7049 rows x 2 columns]

# %%
dataset.isnull().sum()
# Out:
# Smiles    0
# Tm        0
# dtype: int64

# %%
# Checking for duplicate values or duplicate smile string
duplicate = dataset[dataset.duplicated('Smiles')]
 
print("Duplicate Rows based on City :")
 
# Print the resultant Dataframe
print(duplicate)
# Out:
# Duplicate Rows based on City :
#                                   Smiles      Tm
# 111                  C([C@@H](C(=O)O)N)S  513.15
# 186             O=C(O)C(N)CSSCC(N)C(=O)O  533.65
# 197        CCOC(=O)C1(CCN(C)CC1)c2ccccc2  543.15
# 216   Oc1ccc2c(CCC3C2CCC4(C)C(O)CCC34)c1  494.65
# 322                       CSCCC(N)C(=O)O  556.15
# ...                                  ...     ...
# 6932        O=C(O)C1CCC(C)(C(=O)O)C1(C)C  460.15
# 6971    OCC1OC(C(O)C1O)N2C=Nc3c(N)ncnc23  530.40
# 6983                        C1CC2CCCC2C1  243.15
# 7035                 CC=Cc1ccc(O)c(OC)c1  306.65
# 7047                  CC1=CCC(CC1)C(=C)C  198.85
#
# [194 rows x 2 columns]

# %% [markdown]
# - So as we can see from the data there are 187 duplicate smiles strings. So we are removing all of them as we didnot find any relevant feature difference.

# %%
# Removing the duplicates
dataset.drop_duplicates(subset="Smiles", inplace=True)
dataset
# Out:
#                                               Smiles      Tm
# 0                                 O=C(N)Nc1ccc(C)cc1  456.15
# 1       OCC(C(Oc1ccc(cc1)c2ccccc2)N3C=NC=N3)C(C)(C)C  391.15
# 2                      COC(=O)COc1nc(F)c(Cl)c(N)c1Cl  331.35
# 3                                 O=C(O)CNCP(=O)(O)O  533.15
# 4     O=N(=O)c1cc(ccc1C(=O)C2C(=O)CCCC2=O)S(=O)(=O)C  438.15
# ...                                              ...     ...
# 7043         OCC1OC(OC2C(CO)OC(O)C(O)C2O)C(O)C(O)C1O  527.15
# 7044                CCC(C(=O)O)C1(O)CCC(CC1)c2ccccc2  430.15
# 7045                      OCC1CCC(O1)N2C=CC(=O)NC2=O  401.15
# 7046                  CC1CCC2(O)C(C)(C)C3CCC2(C)C1C3  329.15
# 7048                              C1CC2C3CCC(C3)C2C1  350.15
#
# [6855 rows x 2 columns]

# %% [markdown]
# - So after removing all the duplicates we are left with a dataset of shape (5089,2)

# %%
# Standardize the Boiling Point values
mean=dataset['Tm'].mean()
std=dataset['Tm'].std()
dataset['Tm']=(dataset['Tm']-mean)/std
dataset.describe()
print(mean,std)
# Out:
# 352.6430926331145 106.57952607847517

# %%
# Scale the dataset to values between 0 and 1

min_val=dataset['Tm'].min()
max_val=dataset['Tm'].max()
dataset['Tm']=(dataset['Tm']-min_val)/(max_val-min_val)
dataset.describe()
print(max_val,min_val)
# Out:
# 5.108925957936439 -2.5848594262866893

# %%
# Remove noise using Boxplot
# Finding the outliers 
import seaborn as sns

# Plot the boxplot of all columns
sns.boxplot(dataset['Tm'])

# Calculate the upper and lower bounds for each column using the interquartile range (IQR)
Q1 = dataset.quantile(0.25)
Q3 = dataset.quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 2 * IQR
upper_bound = Q3 + 2 * IQR

# Drop the rows containing the outliers in each column
dataset = dataset[~((dataset < lower_bound) | (dataset > upper_bound)).any(axis=1)]
# Out:
# C:\Users\kanad\AppData\Local\Temp\ipykernel_20576\390494786.py:9: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1 = dataset.quantile(0.25)
# C:\Users\kanad\AppData\Local\Temp\ipykernel_20576\390494786.py:10: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q3 = dataset.quantile(0.75)
# C:\Users\kanad\AppData\Local\Temp\ipykernel_20576\390494786.py:16: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   dataset = dataset[~((dataset < lower_bound) | (dataset > upper_bound)).any(axis=1)]
# C:\Users\kanad\AppData\Local\Temp\ipykernel_20576\390494786.py:16: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   dataset = dataset[~((dataset < lower_bound) | (dataset > upper_bound)).any(axis=1)]

# %%
# Train test split 
Train_set, Test_set = train_test_split(dataset, test_size=0.1, shuffle=True, random_state=seed)
Train_set = Train_set.reset_index(drop=True)
Test_set = Test_set.reset_index(drop=True)
val_set,_ = train_test_split(dataset, test_size=0.5, shuffle=True, random_state=seed)
val_set = val_set.reset_index(drop=True)
Train_set
# Out:
#                                                 Smiles        Tm
# 0           OCCNOc1ccc(Cl)cc1C(=O)Nc2ccc(cc2Cl)N(=O)=O  0.502439
# 1                       CCCCCCCCCCCCCCCCCC(=O)OCCC(C)C  0.270122
# 2                          CCCCCCCCCCOc1ccc(cc1)C(=O)O  0.377439
# 3                                         COC(=O)C(O)C  0.158537
# 4                                       Brc1cncc(Br)c1  0.375610
# ...                                                ...       ...
# 6162                              ClC(F)=C(Cl)C(F)(F)F  0.071951
# 6163                            O=C(O)C=Cc1ccc2OCOc2c1  0.535366
# 6164  CCC(CCC(C)C1CCC2C3CCC4CC(O)CCC4(C)C3CCC12C)C(C)C  0.414634
# 6165                                  O=N(=O)Nc1ccccc1  0.296707
# 6166                                         ClCC=CCCl  0.241463
#
# [6167 rows x 2 columns]

# %%
train_mols = make_mol(Train_set)
test_mols = make_mol(Test_set)
val_mols = make_mol(val_set)

train_X = make_vec(train_mols)
test_X = make_vec(test_mols)
val_X = make_vec(val_mols)

#call_pca(train_mols)

# %%
# Model activation

model = torch.load('ECC_model_Tranfer.pt')
model = model.to(device)

# %%
# Printing the model structure
print(model)
# Out:
# GCN_Model_reg(
#   (conv): GCNlayer(
#     (convs): ModuleList(
#       (0): NNConv(128, 128, aggr=add, nn=Sequential(
#         (0): Linear(in_features=6, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=16384, bias=True)
#       ))
#       (1): NNConv(128, 128, aggr=add, nn=Sequential(
#         (0): Linear(in_features=6, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=16384, bias=True)
#       ))
#     )
#     (bns): ModuleList(
#       (0): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (gru): ModuleList(
#       (0): GRU(128, 128)
#       (1): GRU(128, 128)
#     )
#     (lin0): Linear(in_features=30, out_features=128, bias=True)
#     (conv_last): GraphConv(128, 128)
#     (bn_last): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): FClayer(
#     (fcs): ModuleList(
#       (0): Linear(in_features=128, out_features=512, bias=True)
#       (1): Linear(in_features=512, out_features=128, bias=True)
#     )
#     (bns): ModuleList(
#       (0): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (fc_last): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
train_loader = DataLoader(train_X, batch_size=64, shuffle=True, drop_last=True)
val_loader=DataLoader(val_X, batch_size=len(val_X), shuffle=False, drop_last=True)
test_loader = DataLoader(test_X, batch_size=len(test_X), shuffle=False, drop_last=True)

# %%
# Save Checkpoint for model evaluation :
def save_checkpoint(epoch, model, optimizer, filename):
    state = {'Epoch': epoch,'State_dict': model.state_dict(),'optimizer': optimizer.state_dict()}
    torch.save(model, filename)

# %%
def R2_score(y_pred_i,Y):
    #Next we shall compute sigma_yy, which is the variance of y 
    sigma_yy = 0
    for i in range(Y.shape[0]): #access each row from the data set 
       y_i = float(Y[i])
       sigma_yy += (y_i-Y.mean())**2

    #now we can compute sum of squared residuals 
    #print('sigma_yy:', sigma_yy)
    sum_sq_residuals=0
    for i in range(Y.shape[0]): #access each row from the data set 
         y_i = Y[i] #access i-th row of y
         e_i = y_i - y_pred_i[i] #compute the difference between the actual observation y_i and prediction y_pred_i

         sum_sq_residuals += (e_i)**2

    #print('sum of squared residuals:', sum_sq_residuals)

    #Then we will compute the R^2 quantity
    R_sq = 1-sum_sq_residuals/sigma_yy
    return R_sq

# %%
#from sklearn.metrics import r2_score

def train(model, device, optimizer, train_loader, criterion, args):
    train_correct = 0
    train_total = 0
    epoch_train_loss = 0
    for i, data in enumerate(train_loader):
        data = data.to(device)
        targets = data.y.to(device)
        optimizer.zero_grad()
        outputs = model(data)
        
        #print(outputs)
        #print(targets)
        outputs.require_grad = False
        _, predicted = torch.max(outputs.data, 1)
        train_total += targets.size(0)

        correct_dim_output=outputs.squeeze() # done to reshape the outputs and match with targets
        score=R2_score(correct_dim_output.detach().cpu().numpy(), targets.detach().cpu().numpy())
        loss = criterion(correct_dim_output, targets)
        epoch_train_loss += loss.item()
        loss.backward()
        optimizer.step()
    epoch_train_loss /= len(train_loader)
    #print('- Loss : %.4f' % epoch_train_loss)
    return model, epoch_train_loss,score

# %%
def test(model, device, test_loader, args):
    train_total = 0
    y_score=[]
    y_test=[]
    with torch.no_grad():
     for i, data in enumerate(test_loader):
        data = data.to(device)
        targets = data.y.to(device)
        outputs = model(data)
        #print(outputs)
        #print(targets)
        outputs.require_grad = False
        _, predicted = torch.max(outputs.data, 1)
        train_total += targets.size(0)

        correct_dim_output=outputs.squeeze() # done to reshape the outputs and match with targets
        #y_score.append(outputs.cpu().numpy())
        #y_test.append(targets.cpu().numpy())
        test_score=R2_score(outputs.cpu().numpy(),targets.cpu().numpy())
        print("R2 Score Validation test set:",R2_score(outputs.cpu().numpy(),targets.cpu().numpy()))
    return test_score,model,outputs.cpu().numpy(),targets.cpu().numpy()

# %%
def experiment(model, train_loader, device, args):

    
    optimizer = optim.Adam(model.parameters(), lr=args.lr,weight_decay=5e-4) # Add l2 regularizer ??  # ,weight_decay=0.001
    criterion = nn.HuberLoss() # decide on type of losses later
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=args.step_size, gamma=args.gamma)
    
    list_train_loss = list()
    print('[Train]')
    counter=0
    train_r2_score=0.90
    val_r2_score=0.85
    for epoch in range(args.epoch):
        model.train()
        model, train_loss,score= train(model, device, optimizer, train_loader, criterion, args)
        print('- Epoch :', epoch+1,'- Loss : %.5f' % train_loss,'- Train R2 score : %.4f' % score)
        list_train_loss.append(train_loss)

        # Learning rate Updatation scheme when loss not decreasing
        if(epoch!=0):
            #print(train_loss[int(epoch)],train_loss[int(epoch-1)])
            if(round(list_train_loss[epoch],5)>=round(list_train_loss[epoch-1],5)):
                counter+=1
            else:
                counter=0
        if(train_loss<0.0002 and counter>=10):
           counter=0
           args.lr = optimizer.param_groups[0]['lr']*0.5
           print("\nLearning rate changed :",args.lr)
           optimizer = optim.Adam(model.parameters(), lr=args.lr,weight_decay=5e-4)
           scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=args.step_size, gamma=args.gamma)


        val_score,_,_,_=test(model, device,test_loader, args)

        # Saving the best model which has the highest R2 value
        if(val_score>val_r2_score):  # and score>train_r2_score  # Changed
            val_r2_score=val_score
            train_r2_score=score   
            print("Saving Model of score:",val_score,score)       
            save_checkpoint(epoch, model, optimizer, 'ECC_model_Tranfer.pt')  # Saving the best model
            
        scheduler.step()
    
    return args

# %%
result = vars(experiment(model, train_loader, device, args))
# Out:
# [Train]
# - Epoch : 1 - Loss : 0.00172 - Train R2 score : 0.8562
# R2 Score Validation test set: [0.82479346]
# - Epoch : 2 - Loss : 0.00166 - Train R2 score : 0.8219
# R2 Score Validation test set: [0.8272522]
# - Epoch : 3 - Loss : 0.00166 - Train R2 score : 0.7641
# R2 Score Validation test set: [0.79527164]
# - Epoch : 4 - Loss : 0.00170 - Train R2 score : 0.8186
# R2 Score Validation test set: [0.8273344]
# - Epoch : 5 - Loss : 0.00167 - Train R2 score : 0.8333
# R2 Score Validation test set: [0.8178941]
# - Epoch : 6 - Loss : 0.00169 - Train R2 score : 0.8015
# R2 Score Validation test set: [0.8103702]
# - Epoch : 7 - Loss : 0.00166 - Train R2 score : 0.7489
# R2 Score Validation test set: [0.8373244]
# - Epoch : 8 - Loss : 0.00166 - Train R2 score : 0.8331
# R2 Score Validation test set: [0.8231473]
# - Epoch : 9 - Loss : 0.00167 - Train R2 score : 0.8220
# R2 Score Validation test set: [0.8219563]
# - Epoch : 10 - Loss : 0.00169 - Train R2 score : 0.7397
# R2 Score Validation test set: [0.82368886]
# - Epoch : 11 - Loss : 0.00170 - Train R2 score : 0.8280
# R2 Score Validation test set: [0.8184249]
# - Epoch : 12 - Loss : 0.00170 - Train R2 score : 0.8613
# R2 Score Validation test set: [0.8189299]
# - Epoch : 13 - Loss : 0.00163 - Train R2 score : 0.8197
# R2 Score Validation test set: [0.81490165]
# - Epoch : 14 - Loss : 0.00159 - Train R2 score : 0.8777
# R2 Score Validation test set: [0.813809]
# - Epoch : 15 - Loss : 0.00166 - Train R2 score : 0.7895
# R2 Score Validation test set: [0.807314]
# - Epoch : 16 - Loss : 0.00163 - Train R2 score : 0.8316
# R2 Score Validation test set: [0.83161247]
# - Epoch : 17 - Loss : 0.00165 - Train R2 score : 0.7588
# R2 Score Validation test set: [0.8086761]
# - Epoch : 18 - Loss : 0.00167 - Train R2 score : 0.8461
# R2 Score Validation test set: [0.812409]
# - Epoch : 19 - Loss : 0.00164 - Train R2 score : 0.8501
# R2 Score Validation test set: [0.81824297]
# - Epoch : 20 - Loss : 0.00168 - Train R2 score : 0.7956
# R2 Score Validation test set: [0.8209595]
# - Epoch : 21 - Loss : 0.00162 - Train R2 score : 0.8721
# R2 Score Validation test set: [0.82059383]
# - Epoch : 22 - Loss : 0.00160 - Train R2 score : 0.6790
# R2 Score Validation test set: [0.81653243]
# - Epoch : 23 - Loss : 0.00159 - Train R2 score : 0.7932
# R2 Score Validation test set: [0.8243504]
# - Epoch : 24 - Loss : 0.00168 - Train R2 score : 0.7087
# R2 Score Validation test set: [0.8131453]
# - Epoch : 25 - Loss : 0.00163 - Train R2 score : 0.7712
# R2 Score Validation test set: [0.82039714]
# - Epoch : 26 - Loss : 0.00160 - Train R2 score : 0.7567
# R2 Score Validation test set: [0.83370787]
# - Epoch : 27 - Loss : 0.00156 - Train R2 score : 0.8599
# R2 Score Validation test set: [0.80867136]
# - Epoch : 28 - Loss : 0.00157 - Train R2 score : 0.7301
# R2 Score Validation test set: [0.825825]
# - Epoch : 29 - Loss : 0.00156 - Train R2 score : 0.8276
# R2 Score Validation test set: [0.8126808]
# - Epoch : 30 - Loss : 0.00159 - Train R2 score : 0.8289
# R2 Score Validation test set: [0.8361268]
# - Epoch : 31 - Loss : 0.00152 - Train R2 score : 0.8836
# R2 Score Validation test set: [0.8242501]
# - Epoch : 32 - Loss : 0.00159 - Train R2 score : 0.8845
# R2 Score Validation test set: [0.83926]
# - Epoch : 33 - Loss : 0.00158 - Train R2 score : 0.7018
# R2 Score Validation test set: [0.8325595]
# - Epoch : 34 - Loss : 0.00157 - Train R2 score : 0.7444
# R2 Score Validation test set: [0.8137092]
# - Epoch : 35 - Loss : 0.00157 - Train R2 score : 0.7793
# R2 Score Validation test set: [0.82436985]
# - Epoch : 36 - Loss : 0.00156 - Train R2 score : 0.6820
# R2 Score Validation test set: [0.81875014]
# - Epoch : 37 - Loss : 0.00153 - Train R2 score : 0.7209
# R2 Score Validation test set: [0.8413929]
# - Epoch : 38 - Loss : 0.00150 - Train R2 score : 0.7240
# R2 Score Validation test set: [0.8331737]
# - Epoch : 39 - Loss : 0.00158 - Train R2 score : 0.5982
# R2 Score Validation test set: [0.8269723]
# - Epoch : 40 - Loss : 0.00151 - Train R2 score : 0.8096
# R2 Score Validation test set: [0.8338772]
# - Epoch : 41 - Loss : 0.00150 - Train R2 score : 0.8021
# R2 Score Validation test set: [0.83071125]
# - Epoch : 42 - Loss : 0.00150 - Train R2 score : 0.8420
# R2 Score Validation test set: [0.83250123]
# - Epoch : 43 - Loss : 0.00155 - Train R2 score : 0.8310
# R2 Score Validation test set: [0.8371894]
# - Epoch : 44 - Loss : 0.00152 - Train R2 score : 0.8247
# R2 Score Validation test set: [0.81974596]
# - Epoch : 45 - Loss : 0.00155 - Train R2 score : 0.8164
# R2 Score Validation test set: [0.8219158]
# - Epoch : 46 - Loss : 0.00153 - Train R2 score : 0.8216
# R2 Score Validation test set: [0.826486]
# - Epoch : 47 - Loss : 0.00147 - Train R2 score : 0.8653
# R2 Score Validation test set: [0.8386724]
# - Epoch : 48 - Loss : 0.00154 - Train R2 score : 0.8307
# R2 Score Validation test set: [0.83146095]
# - Epoch : 49 - Loss : 0.00150 - Train R2 score : 0.8062
# R2 Score Validation test set: [0.8336438]
# - Epoch : 50 - Loss : 0.00152 - Train R2 score : 0.8214
# R2 Score Validation test set: [0.8361857]
# - Epoch : 51 - Loss : 0.00153 - Train R2 score : 0.8189
# R2 Score Validation test set: [0.8397229]
# - Epoch : 52 - Loss : 0.00147 - Train R2 score : 0.8521
# R2 Score Validation test set: [0.82896596]
# - Epoch : 53 - Loss : 0.00151 - Train R2 score : 0.8757
# R2 Score Validation test set: [0.83946794]
# - Epoch : 54 - Loss : 0.00148 - Train R2 score : 0.8266
# R2 Score Validation test set: [0.833329]
# - Epoch : 55 - Loss : 0.00146 - Train R2 score : 0.7942
# R2 Score Validation test set: [0.83988696]
# - Epoch : 56 - Loss : 0.00146 - Train R2 score : 0.9047
# R2 Score Validation test set: [0.8296982]
# - Epoch : 57 - Loss : 0.00148 - Train R2 score : 0.8651
# R2 Score Validation test set: [0.84009916]
# - Epoch : 58 - Loss : 0.00144 - Train R2 score : 0.8653
# R2 Score Validation test set: [0.8432016]
# - Epoch : 59 - Loss : 0.00145 - Train R2 score : 0.7704
# R2 Score Validation test set: [0.84166336]
# - Epoch : 60 - Loss : 0.00142 - Train R2 score : 0.7615
# R2 Score Validation test set: [0.83898526]
# - Epoch : 61 - Loss : 0.00145 - Train R2 score : 0.8360
# R2 Score Validation test set: [0.8388599]
# - Epoch : 62 - Loss : 0.00149 - Train R2 score : 0.8565
# R2 Score Validation test set: [0.8399795]
# - Epoch : 63 - Loss : 0.00141 - Train R2 score : 0.8599
# R2 Score Validation test set: [0.8392508]
# - Epoch : 64 - Loss : 0.00144 - Train R2 score : 0.7963
# R2 Score Validation test set: [0.8476737]
# - Epoch : 65 - Loss : 0.00146 - Train R2 score : 0.7690
# R2 Score Validation test set: [0.8458137]
# - Epoch : 66 - Loss : 0.00147 - Train R2 score : 0.8427
# R2 Score Validation test set: [0.83387995]
# - Epoch : 67 - Loss : 0.00149 - Train R2 score : 0.7636
# R2 Score Validation test set: [0.81366587]
# - Epoch : 68 - Loss : 0.00148 - Train R2 score : 0.8104
# R2 Score Validation test set: [0.83251756]
# - Epoch : 69 - Loss : 0.00144 - Train R2 score : 0.8704
# R2 Score Validation test set: [0.8324424]
# - Epoch : 70 - Loss : 0.00144 - Train R2 score : 0.8490
# R2 Score Validation test set: [0.851494]
# Saving Model of score: [0.851494] 0.8490474007623608
# - Epoch : 71 - Loss : 0.00144 - Train R2 score : 0.8433
# R2 Score Validation test set: [0.8412639]
# - Epoch : 72 - Loss : 0.00150 - Train R2 score : 0.8246
# R2 Score Validation test set: [0.8355888]
# - Epoch : 73 - Loss : 0.00145 - Train R2 score : 0.8103
# R2 Score Validation test set: [0.8347935]
# - Epoch : 74 - Loss : 0.00144 - Train R2 score : 0.8312
# R2 Score Validation test set: [0.82740694]
# - Epoch : 75 - Loss : 0.00149 - Train R2 score : 0.8474
# R2 Score Validation test set: [0.8361564]
# - Epoch : 76 - Loss : 0.00139 - Train R2 score : 0.8313
# R2 Score Validation test set: [0.84219307]
# - Epoch : 77 - Loss : 0.00139 - Train R2 score : 0.8184
# R2 Score Validation test set: [0.8414694]
# - Epoch : 78 - Loss : 0.00140 - Train R2 score : 0.8213
# R2 Score Validation test set: [0.8400709]
# - Epoch : 79 - Loss : 0.00147 - Train R2 score : 0.8119
# R2 Score Validation test set: [0.8178738]
# - Epoch : 80 - Loss : 0.00140 - Train R2 score : 0.8240
# R2 Score Validation test set: [0.84424865]
# - Epoch : 81 - Loss : 0.00144 - Train R2 score : 0.9126
# R2 Score Validation test set: [0.8318858]
# - Epoch : 82 - Loss : 0.00141 - Train R2 score : 0.8553
# R2 Score Validation test set: [0.8350694]
# - Epoch : 83 - Loss : 0.00144 - Train R2 score : 0.7110
# R2 Score Validation test set: [0.84522897]
# - Epoch : 84 - Loss : 0.00141 - Train R2 score : 0.8166
# R2 Score Validation test set: [0.8415626]
# - Epoch : 85 - Loss : 0.00141 - Train R2 score : 0.8494
# R2 Score Validation test set: [0.8386828]
# - Epoch : 86 - Loss : 0.00139 - Train R2 score : 0.8083
# R2 Score Validation test set: [0.8423798]
# - Epoch : 87 - Loss : 0.00139 - Train R2 score : 0.8844
# R2 Score Validation test set: [0.8302771]
# - Epoch : 88 - Loss : 0.00138 - Train R2 score : 0.8705
# R2 Score Validation test set: [0.84473073]
# - Epoch : 89 - Loss : 0.00136 - Train R2 score : 0.7939
# R2 Score Validation test set: [0.84457654]
# - Epoch : 90 - Loss : 0.00132 - Train R2 score : 0.8972
# R2 Score Validation test set: [0.84487593]
# - Epoch : 91 - Loss : 0.00145 - Train R2 score : 0.8987
# R2 Score Validation test set: [0.8447314]
# - Epoch : 92 - Loss : 0.00144 - Train R2 score : 0.8621
# R2 Score Validation test set: [0.83052456]
# - Epoch : 93 - Loss : 0.00141 - Train R2 score : 0.7344
# R2 Score Validation test set: [0.8296484]
# - Epoch : 94 - Loss : 0.00140 - Train R2 score : 0.8057
# R2 Score Validation test set: [0.85097945]
# - Epoch : 95 - Loss : 0.00142 - Train R2 score : 0.7599
# R2 Score Validation test set: [0.8246653]
# - Epoch : 96 - Loss : 0.00138 - Train R2 score : 0.8236
# R2 Score Validation test set: [0.82878435]
# - Epoch : 97 - Loss : 0.00145 - Train R2 score : 0.8188
# R2 Score Validation test set: [0.83406925]
# - Epoch : 98 - Loss : 0.00146 - Train R2 score : 0.8029
# R2 Score Validation test set: [0.84640515]
# - Epoch : 99 - Loss : 0.00139 - Train R2 score : 0.9012
# R2 Score Validation test set: [0.8344235]
# - Epoch : 100 - Loss : 0.00139 - Train R2 score : 0.7973
# R2 Score Validation test set: [0.8487515]
# - Epoch : 101 - Loss : 0.00136 - Train R2 score : 0.7406
# R2 Score Validation test set: [0.85512584]
# Saving Model of score: [0.85512584] 0.7406002377028269
# - Epoch : 102 - Loss : 0.00136 - Train R2 score : 0.8411
# R2 Score Validation test set: [0.8512612]
# - Epoch : 103 - Loss : 0.00137 - Train R2 score : 0.8548
# R2 Score Validation test set: [0.8451429]
# - Epoch : 104 - Loss : 0.00134 - Train R2 score : 0.8849
# R2 Score Validation test set: [0.84925026]
# - Epoch : 105 - Loss : 0.00137 - Train R2 score : 0.7563
# R2 Score Validation test set: [0.8394954]
# - Epoch : 106 - Loss : 0.00139 - Train R2 score : 0.8583
# R2 Score Validation test set: [0.8485412]
# - Epoch : 107 - Loss : 0.00139 - Train R2 score : 0.8923
# R2 Score Validation test set: [0.8374211]
# - Epoch : 108 - Loss : 0.00138 - Train R2 score : 0.8908
# R2 Score Validation test set: [0.84610516]
# - Epoch : 109 - Loss : 0.00138 - Train R2 score : 0.8606
# R2 Score Validation test set: [0.8390848]
# - Epoch : 110 - Loss : 0.00137 - Train R2 score : 0.8367
# R2 Score Validation test set: [0.8419766]
# - Epoch : 111 - Loss : 0.00142 - Train R2 score : 0.7841
# R2 Score Validation test set: [0.8513341]
# - Epoch : 112 - Loss : 0.00137 - Train R2 score : 0.7951
# R2 Score Validation test set: [0.83849555]
# - Epoch : 113 - Loss : 0.00134 - Train R2 score : 0.8485
# R2 Score Validation test set: [0.84659827]
# - Epoch : 114 - Loss : 0.00138 - Train R2 score : 0.8440
# R2 Score Validation test set: [0.83444834]
# - Epoch : 115 - Loss : 0.00138 - Train R2 score : 0.8220
# R2 Score Validation test set: [0.8388864]
# - Epoch : 116 - Loss : 0.00129 - Train R2 score : 0.8395
# R2 Score Validation test set: [0.84129596]
# - Epoch : 117 - Loss : 0.00131 - Train R2 score : 0.8207
# R2 Score Validation test set: [0.8365708]
# - Epoch : 118 - Loss : 0.00131 - Train R2 score : 0.8561
# R2 Score Validation test set: [0.8316393]
# - Epoch : 119 - Loss : 0.00132 - Train R2 score : 0.8306
# R2 Score Validation test set: [0.8310032]
# - Epoch : 120 - Loss : 0.00132 - Train R2 score : 0.8615
# R2 Score Validation test set: [0.8447505]
# - Epoch : 121 - Loss : 0.00135 - Train R2 score : 0.8096
# R2 Score Validation test set: [0.83978003]
# - Epoch : 122 - Loss : 0.00139 - Train R2 score : 0.8500
# R2 Score Validation test set: [0.83921]
# - Epoch : 123 - Loss : 0.00127 - Train R2 score : 0.8704
# R2 Score Validation test set: [0.84140253]
# - Epoch : 124 - Loss : 0.00138 - Train R2 score : 0.8222
# R2 Score Validation test set: [0.8484538]
# - Epoch : 125 - Loss : 0.00135 - Train R2 score : 0.6838
# R2 Score Validation test set: [0.83430666]
# - Epoch : 126 - Loss : 0.00132 - Train R2 score : 0.8829
# R2 Score Validation test set: [0.8492018]
# - Epoch : 127 - Loss : 0.00131 - Train R2 score : 0.8748
# R2 Score Validation test set: [0.8455295]
# - Epoch : 128 - Loss : 0.00133 - Train R2 score : 0.8521
# R2 Score Validation test set: [0.8437495]
# - Epoch : 129 - Loss : 0.00130 - Train R2 score : 0.8479
# R2 Score Validation test set: [0.8454277]
# - Epoch : 130 - Loss : 0.00130 - Train R2 score : 0.8615
# R2 Score Validation test set: [0.84776914]
# - Epoch : 131 - Loss : 0.00131 - Train R2 score : 0.8360
# R2 Score Validation test set: [0.845083]
# - Epoch : 132 - Loss : 0.00125 - Train R2 score : 0.8784
# R2 Score Validation test set: [0.8539977]
# - Epoch : 133 - Loss : 0.00130 - Train R2 score : 0.9023
# R2 Score Validation test set: [0.85606766]
# Saving Model of score: [0.85606766] 0.9023152290698004
# - Epoch : 134 - Loss : 0.00134 - Train R2 score : 0.7886
# R2 Score Validation test set: [0.8232902]
# - Epoch : 135 - Loss : 0.00129 - Train R2 score : 0.8949
# R2 Score Validation test set: [0.8429588]
# - Epoch : 136 - Loss : 0.00132 - Train R2 score : 0.8532
# R2 Score Validation test set: [0.8442942]
# - Epoch : 137 - Loss : 0.00129 - Train R2 score : 0.9021
# R2 Score Validation test set: [0.83922154]
# - Epoch : 138 - Loss : 0.00127 - Train R2 score : 0.7970
# R2 Score Validation test set: [0.829512]
# - Epoch : 139 - Loss : 0.00132 - Train R2 score : 0.7834
# R2 Score Validation test set: [0.83514684]
# - Epoch : 140 - Loss : 0.00135 - Train R2 score : 0.7975
# R2 Score Validation test set: [0.838978]
# - Epoch : 141 - Loss : 0.00133 - Train R2 score : 0.8528
# R2 Score Validation test set: [0.84675527]
# - Epoch : 142 - Loss : 0.00128 - Train R2 score : 0.8881
# R2 Score Validation test set: [0.8408318]
# - Epoch : 143 - Loss : 0.00124 - Train R2 score : 0.8958
# R2 Score Validation test set: [0.8391765]
# - Epoch : 144 - Loss : 0.00132 - Train R2 score : 0.8528
# R2 Score Validation test set: [0.84830076]
# - Epoch : 145 - Loss : 0.00138 - Train R2 score : 0.8176
# R2 Score Validation test set: [0.844709]
# - Epoch : 146 - Loss : 0.00130 - Train R2 score : 0.8291
# R2 Score Validation test set: [0.848228]
# - Epoch : 147 - Loss : 0.00130 - Train R2 score : 0.8469
# R2 Score Validation test set: [0.8467464]
# - Epoch : 148 - Loss : 0.00131 - Train R2 score : 0.8242
# R2 Score Validation test set: [0.8360424]
# - Epoch : 149 - Loss : 0.00137 - Train R2 score : 0.9026
# R2 Score Validation test set: [0.83309734]
# - Epoch : 150 - Loss : 0.00127 - Train R2 score : 0.7966
# R2 Score Validation test set: [0.8413172]
# - Epoch : 151 - Loss : 0.00127 - Train R2 score : 0.8858
# R2 Score Validation test set: [0.83611786]
# - Epoch : 152 - Loss : 0.00129 - Train R2 score : 0.8653
# R2 Score Validation test set: [0.849174]
# - Epoch : 153 - Loss : 0.00125 - Train R2 score : 0.7950
# R2 Score Validation test set: [0.85241044]
# - Epoch : 154 - Loss : 0.00127 - Train R2 score : 0.8627
# R2 Score Validation test set: [0.8327966]
# - Epoch : 155 - Loss : 0.00125 - Train R2 score : 0.8614
# R2 Score Validation test set: [0.8502292]
# - Epoch : 156 - Loss : 0.00124 - Train R2 score : 0.8067
# R2 Score Validation test set: [0.8496879]
# - Epoch : 157 - Loss : 0.00122 - Train R2 score : 0.8411
# R2 Score Validation test set: [0.8403043]
# - Epoch : 158 - Loss : 0.00124 - Train R2 score : 0.8807
# R2 Score Validation test set: [0.8554359]
# - Epoch : 159 - Loss : 0.00122 - Train R2 score : 0.9000
# R2 Score Validation test set: [0.8443692]
# - Epoch : 160 - Loss : 0.00126 - Train R2 score : 0.8643
# R2 Score Validation test set: [0.8454245]
# - Epoch : 161 - Loss : 0.00125 - Train R2 score : 0.7511
# R2 Score Validation test set: [0.8347685]
# - Epoch : 162 - Loss : 0.00125 - Train R2 score : 0.9069
# R2 Score Validation test set: [0.8549707]
# - Epoch : 163 - Loss : 0.00126 - Train R2 score : 0.8738
# R2 Score Validation test set: [0.84573644]
# - Epoch : 164 - Loss : 0.00122 - Train R2 score : 0.9133
# R2 Score Validation test set: [0.84850556]
# - Epoch : 165 - Loss : 0.00129 - Train R2 score : 0.8781
# R2 Score Validation test set: [0.8482706]
# - Epoch : 166 - Loss : 0.00124 - Train R2 score : 0.7752
# R2 Score Validation test set: [0.84251475]
# - Epoch : 167 - Loss : 0.00131 - Train R2 score : 0.8583
# R2 Score Validation test set: [0.83859545]
# - Epoch : 168 - Loss : 0.00129 - Train R2 score : 0.9316
# R2 Score Validation test set: [0.84418225]
# - Epoch : 169 - Loss : 0.00128 - Train R2 score : 0.8869
# R2 Score Validation test set: [0.8428384]
# - Epoch : 170 - Loss : 0.00126 - Train R2 score : 0.7489
# R2 Score Validation test set: [0.85514176]
# - Epoch : 171 - Loss : 0.00123 - Train R2 score : 0.8337
# R2 Score Validation test set: [0.8523833]
# - Epoch : 172 - Loss : 0.00126 - Train R2 score : 0.9032
# R2 Score Validation test set: [0.8455007]
# - Epoch : 173 - Loss : 0.00125 - Train R2 score : 0.8493
# R2 Score Validation test set: [0.85190177]
# - Epoch : 174 - Loss : 0.00124 - Train R2 score : 0.8363
# R2 Score Validation test set: [0.8583708]
# Saving Model of score: [0.8583708] 0.8363060473325945
# - Epoch : 175 - Loss : 0.00126 - Train R2 score : 0.8225
# R2 Score Validation test set: [0.83608687]
# - Epoch : 176 - Loss : 0.00118 - Train R2 score : 0.8718
# R2 Score Validation test set: [0.84236264]
# - Epoch : 177 - Loss : 0.00128 - Train R2 score : 0.8961
# R2 Score Validation test set: [0.84358984]
# - Epoch : 178 - Loss : 0.00126 - Train R2 score : 0.8681
# R2 Score Validation test set: [0.84758747]
# - Epoch : 179 - Loss : 0.00125 - Train R2 score : 0.9141
# R2 Score Validation test set: [0.8421811]
# - Epoch : 180 - Loss : 0.00124 - Train R2 score : 0.8812
# R2 Score Validation test set: [0.83470774]
# - Epoch : 181 - Loss : 0.00124 - Train R2 score : 0.8750
# R2 Score Validation test set: [0.84657514]
# - Epoch : 182 - Loss : 0.00121 - Train R2 score : 0.7641
# R2 Score Validation test set: [0.8626868]
# Saving Model of score: [0.8626868] 0.7641037056646112
# - Epoch : 183 - Loss : 0.00123 - Train R2 score : 0.8294
# R2 Score Validation test set: [0.8434704]
# - Epoch : 184 - Loss : 0.00122 - Train R2 score : 0.8848
# R2 Score Validation test set: [0.85299194]
# - Epoch : 185 - Loss : 0.00125 - Train R2 score : 0.8095
# R2 Score Validation test set: [0.8427313]
# - Epoch : 186 - Loss : 0.00122 - Train R2 score : 0.8101
# R2 Score Validation test set: [0.8432336]
# - Epoch : 187 - Loss : 0.00125 - Train R2 score : 0.8694
# R2 Score Validation test set: [0.8399857]
# - Epoch : 188 - Loss : 0.00125 - Train R2 score : 0.7477
# R2 Score Validation test set: [0.8508967]
# - Epoch : 189 - Loss : 0.00121 - Train R2 score : 0.7692
# R2 Score Validation test set: [0.84334964]
# - Epoch : 190 - Loss : 0.00128 - Train R2 score : 0.8585
# R2 Score Validation test set: [0.85018754]
# - Epoch : 191 - Loss : 0.00121 - Train R2 score : 0.8068
# R2 Score Validation test set: [0.85068536]
# - Epoch : 192 - Loss : 0.00124 - Train R2 score : 0.9132
# R2 Score Validation test set: [0.8541091]
# - Epoch : 193 - Loss : 0.00121 - Train R2 score : 0.8714
# R2 Score Validation test set: [0.8440844]
# - Epoch : 194 - Loss : 0.00118 - Train R2 score : 0.9130
# R2 Score Validation test set: [0.8479829]
# - Epoch : 195 - Loss : 0.00124 - Train R2 score : 0.8286
# R2 Score Validation test set: [0.85075665]
# - Epoch : 196 - Loss : 0.00121 - Train R2 score : 0.8401
# R2 Score Validation test set: [0.860239]
# - Epoch : 197 - Loss : 0.00125 - Train R2 score : 0.8409
# R2 Score Validation test set: [0.8407508]
# - Epoch : 198 - Loss : 0.00123 - Train R2 score : 0.8562
# R2 Score Validation test set: [0.8523504]
# - Epoch : 199 - Loss : 0.00123 - Train R2 score : 0.8847
# R2 Score Validation test set: [0.85080034]
# - Epoch : 200 - Loss : 0.00122 - Train R2 score : 0.8356
# R2 Score Validation test set: [0.8460982]
# - Epoch : 201 - Loss : 0.00122 - Train R2 score : 0.9026
# R2 Score Validation test set: [0.8475414]
# - Epoch : 202 - Loss : 0.00121 - Train R2 score : 0.9154
# R2 Score Validation test set: [0.84648067]
# - Epoch : 203 - Loss : 0.00117 - Train R2 score : 0.8305
# R2 Score Validation test set: [0.83616483]
# - Epoch : 204 - Loss : 0.00123 - Train R2 score : 0.9100
# R2 Score Validation test set: [0.8466749]
# - Epoch : 205 - Loss : 0.00120 - Train R2 score : 0.8539
# R2 Score Validation test set: [0.8438633]
# - Epoch : 206 - Loss : 0.00128 - Train R2 score : 0.8175
# R2 Score Validation test set: [0.8487196]
# - Epoch : 207 - Loss : 0.00119 - Train R2 score : 0.7973
# R2 Score Validation test set: [0.8560781]
# - Epoch : 208 - Loss : 0.00122 - Train R2 score : 0.8191
# R2 Score Validation test set: [0.86537325]
# Saving Model of score: [0.86537325] 0.8191372295998639
# - Epoch : 209 - Loss : 0.00124 - Train R2 score : 0.8390
# R2 Score Validation test set: [0.85277736]
# - Epoch : 210 - Loss : 0.00119 - Train R2 score : 0.8692
# R2 Score Validation test set: [0.8489207]
# - Epoch : 211 - Loss : 0.00122 - Train R2 score : 0.7714
# R2 Score Validation test set: [0.84037566]
# - Epoch : 212 - Loss : 0.00122 - Train R2 score : 0.8824
# R2 Score Validation test set: [0.8488815]
# - Epoch : 213 - Loss : 0.00120 - Train R2 score : 0.9047
# R2 Score Validation test set: [0.8480041]
# - Epoch : 214 - Loss : 0.00116 - Train R2 score : 0.8864
# R2 Score Validation test set: [0.8576518]
# - Epoch : 215 - Loss : 0.00123 - Train R2 score : 0.8435
# R2 Score Validation test set: [0.84494054]
# - Epoch : 216 - Loss : 0.00122 - Train R2 score : 0.8820
# R2 Score Validation test set: [0.84838676]
# - Epoch : 217 - Loss : 0.00121 - Train R2 score : 0.8186
# R2 Score Validation test set: [0.8479677]
# - Epoch : 218 - Loss : 0.00124 - Train R2 score : 0.8733
# R2 Score Validation test set: [0.852119]
# - Epoch : 219 - Loss : 0.00122 - Train R2 score : 0.9138
# R2 Score Validation test set: [0.85074556]
# - Epoch : 220 - Loss : 0.00121 - Train R2 score : 0.7742
# R2 Score Validation test set: [0.8454703]
# - Epoch : 221 - Loss : 0.00116 - Train R2 score : 0.9174
# R2 Score Validation test set: [0.844584]
# - Epoch : 222 - Loss : 0.00120 - Train R2 score : 0.8852
# R2 Score Validation test set: [0.8470422]
# - Epoch : 223 - Loss : 0.00119 - Train R2 score : 0.8213
# R2 Score Validation test set: [0.8576545]
# - Epoch : 224 - Loss : 0.00118 - Train R2 score : 0.8946
# R2 Score Validation test set: [0.84274805]
# - Epoch : 225 - Loss : 0.00120 - Train R2 score : 0.6852
# R2 Score Validation test set: [0.85301936]
# - Epoch : 226 - Loss : 0.00120 - Train R2 score : 0.8999
# R2 Score Validation test set: [0.83834696]
# - Epoch : 227 - Loss : 0.00119 - Train R2 score : 0.8564
# R2 Score Validation test set: [0.84951925]
# - Epoch : 228 - Loss : 0.00119 - Train R2 score : 0.8711
# R2 Score Validation test set: [0.84804434]
# - Epoch : 229 - Loss : 0.00116 - Train R2 score : 0.8494
# R2 Score Validation test set: [0.8455526]
# - Epoch : 230 - Loss : 0.00127 - Train R2 score : 0.8121
# R2 Score Validation test set: [0.8517381]
# - Epoch : 231 - Loss : 0.00124 - Train R2 score : 0.6431
# R2 Score Validation test set: [0.8466008]
# - Epoch : 232 - Loss : 0.00118 - Train R2 score : 0.8340
# R2 Score Validation test set: [0.8487736]
# - Epoch : 233 - Loss : 0.00117 - Train R2 score : 0.8836
# R2 Score Validation test set: [0.8529449]
# - Epoch : 234 - Loss : 0.00117 - Train R2 score : 0.8718
# R2 Score Validation test set: [0.84979546]
# - Epoch : 235 - Loss : 0.00118 - Train R2 score : 0.8226
# R2 Score Validation test set: [0.84653234]
# - Epoch : 236 - Loss : 0.00118 - Train R2 score : 0.8776
# R2 Score Validation test set: [0.84709746]
# - Epoch : 237 - Loss : 0.00121 - Train R2 score : 0.7682
# R2 Score Validation test set: [0.8574961]
# - Epoch : 238 - Loss : 0.00118 - Train R2 score : 0.8355
# R2 Score Validation test set: [0.84599996]
# - Epoch : 239 - Loss : 0.00120 - Train R2 score : 0.8643
# R2 Score Validation test set: [0.84430647]
# - Epoch : 240 - Loss : 0.00115 - Train R2 score : 0.7922
# R2 Score Validation test set: [0.85311013]
# - Epoch : 241 - Loss : 0.00117 - Train R2 score : 0.8549
# R2 Score Validation test set: [0.8533312]
# - Epoch : 242 - Loss : 0.00115 - Train R2 score : 0.9110
# R2 Score Validation test set: [0.853786]
# - Epoch : 243 - Loss : 0.00119 - Train R2 score : 0.8969
# R2 Score Validation test set: [0.8607236]
# - Epoch : 244 - Loss : 0.00116 - Train R2 score : 0.8749
# R2 Score Validation test set: [0.8490984]
# - Epoch : 245 - Loss : 0.00122 - Train R2 score : 0.8078
# R2 Score Validation test set: [0.8494769]
# - Epoch : 246 - Loss : 0.00117 - Train R2 score : 0.8092
# R2 Score Validation test set: [0.84963644]
# - Epoch : 247 - Loss : 0.00120 - Train R2 score : 0.8951
# R2 Score Validation test set: [0.8641823]
# - Epoch : 248 - Loss : 0.00118 - Train R2 score : 0.8958
# R2 Score Validation test set: [0.8499362]
# - Epoch : 249 - Loss : 0.00115 - Train R2 score : 0.8598
# R2 Score Validation test set: [0.85088444]
# - Epoch : 250 - Loss : 0.00118 - Train R2 score : 0.8457
# R2 Score Validation test set: [0.8496827]
# - Epoch : 251 - Loss : 0.00118 - Train R2 score : 0.8888
# R2 Score Validation test set: [0.85085225]
# - Epoch : 252 - Loss : 0.00113 - Train R2 score : 0.8977
# R2 Score Validation test set: [0.8453298]
# - Epoch : 253 - Loss : 0.00115 - Train R2 score : 0.7817
# R2 Score Validation test set: [0.8483279]
# - Epoch : 254 - Loss : 0.00118 - Train R2 score : 0.8406
# R2 Score Validation test set: [0.847894]
# - Epoch : 255 - Loss : 0.00122 - Train R2 score : 0.8077
# R2 Score Validation test set: [0.8547593]
# - Epoch : 256 - Loss : 0.00121 - Train R2 score : 0.8726
# R2 Score Validation test set: [0.85060126]
# - Epoch : 257 - Loss : 0.00120 - Train R2 score : 0.8862
# R2 Score Validation test set: [0.8384259]
# - Epoch : 258 - Loss : 0.00121 - Train R2 score : 0.8691
# R2 Score Validation test set: [0.8469528]
# - Epoch : 259 - Loss : 0.00109 - Train R2 score : 0.8317
# R2 Score Validation test set: [0.8521074]
# - Epoch : 260 - Loss : 0.00119 - Train R2 score : 0.8891
# R2 Score Validation test set: [0.8577163]
# - Epoch : 261 - Loss : 0.00118 - Train R2 score : 0.9019
# R2 Score Validation test set: [0.845691]
# - Epoch : 262 - Loss : 0.00117 - Train R2 score : 0.7725
# R2 Score Validation test set: [0.8539585]
# - Epoch : 263 - Loss : 0.00115 - Train R2 score : 0.9015
# R2 Score Validation test set: [0.8479787]
# - Epoch : 264 - Loss : 0.00117 - Train R2 score : 0.8897
# R2 Score Validation test set: [0.8573964]
# - Epoch : 265 - Loss : 0.00114 - Train R2 score : 0.8596
# R2 Score Validation test set: [0.8498585]
# - Epoch : 266 - Loss : 0.00116 - Train R2 score : 0.8589
# R2 Score Validation test set: [0.85478437]
# - Epoch : 267 - Loss : 0.00116 - Train R2 score : 0.8860
# R2 Score Validation test set: [0.84047997]
# - Epoch : 268 - Loss : 0.00121 - Train R2 score : 0.8689
# R2 Score Validation test set: [0.8452547]
# - Epoch : 269 - Loss : 0.00119 - Train R2 score : 0.9013
# R2 Score Validation test set: [0.84631336]
# - Epoch : 270 - Loss : 0.00113 - Train R2 score : 0.7778
# R2 Score Validation test set: [0.84935915]
# - Epoch : 271 - Loss : 0.00120 - Train R2 score : 0.8761
# R2 Score Validation test set: [0.8416194]
# - Epoch : 272 - Loss : 0.00116 - Train R2 score : 0.8838
# R2 Score Validation test set: [0.8516397]
# - Epoch : 273 - Loss : 0.00120 - Train R2 score : 0.7912
# R2 Score Validation test set: [0.848063]
# - Epoch : 274 - Loss : 0.00118 - Train R2 score : 0.8903
# R2 Score Validation test set: [0.8397689]
# - Epoch : 275 - Loss : 0.00113 - Train R2 score : 0.8743
# R2 Score Validation test set: [0.84741664]
# - Epoch : 276 - Loss : 0.00120 - Train R2 score : 0.8717
# R2 Score Validation test set: [0.853591]
# - Epoch : 277 - Loss : 0.00112 - Train R2 score : 0.8476
# R2 Score Validation test set: [0.8473962]
# - Epoch : 278 - Loss : 0.00117 - Train R2 score : 0.8940
# R2 Score Validation test set: [0.8465281]
# - Epoch : 279 - Loss : 0.00120 - Train R2 score : 0.8279
# R2 Score Validation test set: [0.86246073]
# - Epoch : 280 - Loss : 0.00113 - Train R2 score : 0.8873
# R2 Score Validation test set: [0.8559108]
# - Epoch : 281 - Loss : 0.00111 - Train R2 score : 0.8161
# R2 Score Validation test set: [0.85214055]
# - Epoch : 282 - Loss : 0.00115 - Train R2 score : 0.8604
# R2 Score Validation test set: [0.8420912]
# - Epoch : 283 - Loss : 0.00114 - Train R2 score : 0.6178
# R2 Score Validation test set: [0.84666216]
# - Epoch : 284 - Loss : 0.00115 - Train R2 score : 0.8618
# R2 Score Validation test set: [0.85241014]
# - Epoch : 285 - Loss : 0.00112 - Train R2 score : 0.8527
# R2 Score Validation test set: [0.85614884]
# - Epoch : 286 - Loss : 0.00115 - Train R2 score : 0.9355
# R2 Score Validation test set: [0.8608064]
# - Epoch : 287 - Loss : 0.00110 - Train R2 score : 0.8106
# R2 Score Validation test set: [0.84768397]
# - Epoch : 288 - Loss : 0.00125 - Train R2 score : 0.8923
# R2 Score Validation test set: [0.8452704]
# - Epoch : 289 - Loss : 0.00112 - Train R2 score : 0.7746
# R2 Score Validation test set: [0.84116626]
# - Epoch : 290 - Loss : 0.00115 - Train R2 score : 0.7908
# R2 Score Validation test set: [0.8385833]
# - Epoch : 291 - Loss : 0.00115 - Train R2 score : 0.8088
# R2 Score Validation test set: [0.8500461]
# - Epoch : 292 - Loss : 0.00117 - Train R2 score : 0.8856
# R2 Score Validation test set: [0.85111475]
# - Epoch : 293 - Loss : 0.00114 - Train R2 score : 0.9172
# R2 Score Validation test set: [0.84287566]
# - Epoch : 294 - Loss : 0.00115 - Train R2 score : 0.9345
# R2 Score Validation test set: [0.8472197]
# - Epoch : 295 - Loss : 0.00113 - Train R2 score : 0.8892
# R2 Score Validation test set: [0.8391751]
# - Epoch : 296 - Loss : 0.00113 - Train R2 score : 0.8534
# R2 Score Validation test set: [0.86609656]
# Saving Model of score: [0.86609656] 0.8533902092202073
# - Epoch : 297 - Loss : 0.00114 - Train R2 score : 0.9151
# R2 Score Validation test set: [0.8431101]
# - Epoch : 298 - Loss : 0.00117 - Train R2 score : 0.9164
# R2 Score Validation test set: [0.8431244]
# - Epoch : 299 - Loss : 0.00111 - Train R2 score : 0.8955
# R2 Score Validation test set: [0.8553223]
# - Epoch : 300 - Loss : 0.00120 - Train R2 score : 0.8846
# R2 Score Validation test set: [0.85719067]
# - Epoch : 301 - Loss : 0.00109 - Train R2 score : 0.8652
# R2 Score Validation test set: [0.854941]
# - Epoch : 302 - Loss : 0.00113 - Train R2 score : 0.9087
# R2 Score Validation test set: [0.84870243]
# - Epoch : 303 - Loss : 0.00114 - Train R2 score : 0.8624
# R2 Score Validation test set: [0.8546548]
# - Epoch : 304 - Loss : 0.00115 - Train R2 score : 0.8778
# R2 Score Validation test set: [0.85202146]
# - Epoch : 305 - Loss : 0.00113 - Train R2 score : 0.8303
# R2 Score Validation test set: [0.8491952]
# - Epoch : 306 - Loss : 0.00118 - Train R2 score : 0.8725
# R2 Score Validation test set: [0.85643846]
# - Epoch : 307 - Loss : 0.00111 - Train R2 score : 0.8459
# R2 Score Validation test set: [0.8612215]
# - Epoch : 308 - Loss : 0.00113 - Train R2 score : 0.8386
# R2 Score Validation test set: [0.8454087]
# - Epoch : 309 - Loss : 0.00115 - Train R2 score : 0.9004
# R2 Score Validation test set: [0.84796894]
# - Epoch : 310 - Loss : 0.00114 - Train R2 score : 0.8582
# R2 Score Validation test set: [0.8510753]
# - Epoch : 311 - Loss : 0.00112 - Train R2 score : 0.9000
# R2 Score Validation test set: [0.85334533]
# - Epoch : 312 - Loss : 0.00117 - Train R2 score : 0.8589
# R2 Score Validation test set: [0.8504165]
# - Epoch : 313 - Loss : 0.00116 - Train R2 score : 0.9003
# R2 Score Validation test set: [0.8544806]
# - Epoch : 314 - Loss : 0.00115 - Train R2 score : 0.8603
# R2 Score Validation test set: [0.8535632]
# - Epoch : 315 - Loss : 0.00113 - Train R2 score : 0.8965
# R2 Score Validation test set: [0.85822415]
# - Epoch : 316 - Loss : 0.00116 - Train R2 score : 0.8095
# R2 Score Validation test set: [0.8496029]
# - Epoch : 317 - Loss : 0.00114 - Train R2 score : 0.8664
# R2 Score Validation test set: [0.8515431]
# - Epoch : 318 - Loss : 0.00114 - Train R2 score : 0.8736
# R2 Score Validation test set: [0.8448001]
# - Epoch : 319 - Loss : 0.00113 - Train R2 score : 0.9048
# R2 Score Validation test set: [0.8407572]
# - Epoch : 320 - Loss : 0.00113 - Train R2 score : 0.8343
# R2 Score Validation test set: [0.8455157]
# - Epoch : 321 - Loss : 0.00115 - Train R2 score : 0.7311
# R2 Score Validation test set: [0.8566014]
# - Epoch : 322 - Loss : 0.00115 - Train R2 score : 0.8967
# R2 Score Validation test set: [0.8467644]
# - Epoch : 323 - Loss : 0.00115 - Train R2 score : 0.8252
# R2 Score Validation test set: [0.8541653]
# - Epoch : 324 - Loss : 0.00111 - Train R2 score : 0.9126
# R2 Score Validation test set: [0.8452579]
# - Epoch : 325 - Loss : 0.00116 - Train R2 score : 0.9199
# R2 Score Validation test set: [0.8564517]
# - Epoch : 326 - Loss : 0.00109 - Train R2 score : 0.8712
# R2 Score Validation test set: [0.8556579]
# - Epoch : 327 - Loss : 0.00116 - Train R2 score : 0.9151
# R2 Score Validation test set: [0.8401967]
# - Epoch : 328 - Loss : 0.00113 - Train R2 score : 0.7859
# R2 Score Validation test set: [0.8549854]
# - Epoch : 329 - Loss : 0.00114 - Train R2 score : 0.8565
# R2 Score Validation test set: [0.8373152]
# - Epoch : 330 - Loss : 0.00113 - Train R2 score : 0.8857
# R2 Score Validation test set: [0.84145]
# - Epoch : 331 - Loss : 0.00115 - Train R2 score : 0.8404
# R2 Score Validation test set: [0.8520962]
# - Epoch : 332 - Loss : 0.00113 - Train R2 score : 0.7589
# R2 Score Validation test set: [0.8476107]
# - Epoch : 333 - Loss : 0.00116 - Train R2 score : 0.9132
# R2 Score Validation test set: [0.8353392]
# - Epoch : 334 - Loss : 0.00109 - Train R2 score : 0.8232
# R2 Score Validation test set: [0.8547327]
# - Epoch : 335 - Loss : 0.00113 - Train R2 score : 0.9130
# R2 Score Validation test set: [0.8549542]
# - Epoch : 336 - Loss : 0.00114 - Train R2 score : 0.8208
# R2 Score Validation test set: [0.8492766]
# - Epoch : 337 - Loss : 0.00106 - Train R2 score : 0.8772
# R2 Score Validation test set: [0.8582678]
# - Epoch : 338 - Loss : 0.00115 - Train R2 score : 0.8427
# R2 Score Validation test set: [0.8485938]
# - Epoch : 339 - Loss : 0.00112 - Train R2 score : 0.8470
# R2 Score Validation test set: [0.8618037]
# - Epoch : 340 - Loss : 0.00113 - Train R2 score : 0.8857
# R2 Score Validation test set: [0.8518115]
# - Epoch : 341 - Loss : 0.00112 - Train R2 score : 0.9056
# R2 Score Validation test set: [0.8468394]
# - Epoch : 342 - Loss : 0.00115 - Train R2 score : 0.8795
# R2 Score Validation test set: [0.85390544]
# - Epoch : 343 - Loss : 0.00115 - Train R2 score : 0.8831
# R2 Score Validation test set: [0.85814]
# - Epoch : 344 - Loss : 0.00111 - Train R2 score : 0.9035
# R2 Score Validation test set: [0.8454168]
# - Epoch : 345 - Loss : 0.00117 - Train R2 score : 0.8632
# R2 Score Validation test set: [0.84956217]
# - Epoch : 346 - Loss : 0.00110 - Train R2 score : 0.8825
# R2 Score Validation test set: [0.8567927]
# - Epoch : 347 - Loss : 0.00113 - Train R2 score : 0.9178
# R2 Score Validation test set: [0.8593523]
# - Epoch : 348 - Loss : 0.00110 - Train R2 score : 0.8596
# R2 Score Validation test set: [0.8411276]
# - Epoch : 349 - Loss : 0.00109 - Train R2 score : 0.9035
# R2 Score Validation test set: [0.8581129]
# - Epoch : 350 - Loss : 0.00116 - Train R2 score : 0.8600
# R2 Score Validation test set: [0.8449617]
# - Epoch : 351 - Loss : 0.00111 - Train R2 score : 0.9005
# R2 Score Validation test set: [0.86502105]
# - Epoch : 352 - Loss : 0.00113 - Train R2 score : 0.8431
# R2 Score Validation test set: [0.85749084]
# - Epoch : 353 - Loss : 0.00116 - Train R2 score : 0.8765
# R2 Score Validation test set: [0.8444288]
# - Epoch : 354 - Loss : 0.00107 - Train R2 score : 0.8656
# R2 Score Validation test set: [0.85947335]
# - Epoch : 355 - Loss : 0.00115 - Train R2 score : 0.8800
# R2 Score Validation test set: [0.8441322]
# - Epoch : 356 - Loss : 0.00112 - Train R2 score : 0.8964
# R2 Score Validation test set: [0.8435101]
# - Epoch : 357 - Loss : 0.00113 - Train R2 score : 0.8617
# R2 Score Validation test set: [0.8561355]
# - Epoch : 358 - Loss : 0.00111 - Train R2 score : 0.7591
# R2 Score Validation test set: [0.8471754]
# - Epoch : 359 - Loss : 0.00116 - Train R2 score : 0.9068
# R2 Score Validation test set: [0.83713984]
# - Epoch : 360 - Loss : 0.00109 - Train R2 score : 0.9033
# R2 Score Validation test set: [0.8615132]
# - Epoch : 361 - Loss : 0.00113 - Train R2 score : 0.8697
# R2 Score Validation test set: [0.85061234]
# - Epoch : 362 - Loss : 0.00112 - Train R2 score : 0.8781
# R2 Score Validation test set: [0.8636485]
# - Epoch : 363 - Loss : 0.00116 - Train R2 score : 0.9009
# R2 Score Validation test set: [0.84736514]
# - Epoch : 364 - Loss : 0.00113 - Train R2 score : 0.8867
# R2 Score Validation test set: [0.8562502]
# - Epoch : 365 - Loss : 0.00114 - Train R2 score : 0.8996
# R2 Score Validation test set: [0.8507571]
# - Epoch : 366 - Loss : 0.00113 - Train R2 score : 0.9202
# R2 Score Validation test set: [0.8457743]
# - Epoch : 367 - Loss : 0.00108 - Train R2 score : 0.8421
# R2 Score Validation test set: [0.8589189]
# - Epoch : 368 - Loss : 0.00116 - Train R2 score : 0.9080
# R2 Score Validation test set: [0.8546807]
# - Epoch : 369 - Loss : 0.00113 - Train R2 score : 0.9207
# R2 Score Validation test set: [0.8407637]
# - Epoch : 370 - Loss : 0.00108 - Train R2 score : 0.8786
# R2 Score Validation test set: [0.86064464]
# - Epoch : 371 - Loss : 0.00116 - Train R2 score : 0.8136
# R2 Score Validation test set: [0.8346687]
# - Epoch : 372 - Loss : 0.00118 - Train R2 score : 0.7765
# R2 Score Validation test set: [0.84558654]
# - Epoch : 373 - Loss : 0.00111 - Train R2 score : 0.8180
# R2 Score Validation test set: [0.8570606]
# - Epoch : 374 - Loss : 0.00114 - Train R2 score : 0.8195
# R2 Score Validation test set: [0.85003376]
# - Epoch : 375 - Loss : 0.00112 - Train R2 score : 0.7875
# R2 Score Validation test set: [0.85338]
# - Epoch : 376 - Loss : 0.00108 - Train R2 score : 0.7935
# R2 Score Validation test set: [0.852533]
# - Epoch : 377 - Loss : 0.00111 - Train R2 score : 0.6406
# R2 Score Validation test set: [0.8598334]
# - Epoch : 378 - Loss : 0.00113 - Train R2 score : 0.8466
# R2 Score Validation test set: [0.8551918]
# - Epoch : 379 - Loss : 0.00112 - Train R2 score : 0.7799
# R2 Score Validation test set: [0.8507399]
# - Epoch : 380 - Loss : 0.00112 - Train R2 score : 0.8188
# R2 Score Validation test set: [0.8466965]
# - Epoch : 381 - Loss : 0.00108 - Train R2 score : 0.8784
# R2 Score Validation test set: [0.8502882]
# - Epoch : 382 - Loss : 0.00114 - Train R2 score : 0.9029
# R2 Score Validation test set: [0.84971595]
# - Epoch : 383 - Loss : 0.00121 - Train R2 score : 0.8147
# R2 Score Validation test set: [0.8617046]
# - Epoch : 384 - Loss : 0.00108 - Train R2 score : 0.8610
# R2 Score Validation test set: [0.84863675]
# - Epoch : 385 - Loss : 0.00116 - Train R2 score : 0.8356
# R2 Score Validation test set: [0.8541986]
# - Epoch : 386 - Loss : 0.00112 - Train R2 score : 0.8405
# R2 Score Validation test set: [0.85507864]
# - Epoch : 387 - Loss : 0.00113 - Train R2 score : 0.8549
# R2 Score Validation test set: [0.85514015]
# - Epoch : 388 - Loss : 0.00115 - Train R2 score : 0.9090
# R2 Score Validation test set: [0.8554582]
# - Epoch : 389 - Loss : 0.00111 - Train R2 score : 0.7957
# R2 Score Validation test set: [0.85667837]
# - Epoch : 390 - Loss : 0.00105 - Train R2 score : 0.9003
# R2 Score Validation test set: [0.85909647]
# - Epoch : 391 - Loss : 0.00106 - Train R2 score : 0.8724
# R2 Score Validation test set: [0.8605467]
# - Epoch : 392 - Loss : 0.00114 - Train R2 score : 0.9122
# R2 Score Validation test set: [0.8662757]
# Saving Model of score: [0.8662757] 0.9122264174463346
# - Epoch : 393 - Loss : 0.00111 - Train R2 score : 0.9090
# R2 Score Validation test set: [0.84429836]
# - Epoch : 394 - Loss : 0.00109 - Train R2 score : 0.8886
# R2 Score Validation test set: [0.8465202]
# - Epoch : 395 - Loss : 0.00109 - Train R2 score : 0.8715
# R2 Score Validation test set: [0.84842956]
# - Epoch : 396 - Loss : 0.00119 - Train R2 score : 0.7037
# R2 Score Validation test set: [0.8574691]
# - Epoch : 397 - Loss : 0.00114 - Train R2 score : 0.8951
# R2 Score Validation test set: [0.85895944]
# - Epoch : 398 - Loss : 0.00109 - Train R2 score : 0.8559
# R2 Score Validation test set: [0.84988534]
# - Epoch : 399 - Loss : 0.00111 - Train R2 score : 0.9181
# R2 Score Validation test set: [0.8535743]
# - Epoch : 400 - Loss : 0.00114 - Train R2 score : 0.6998
# R2 Score Validation test set: [0.8517822]

# %%
import gc

torch.cuda.empty_cache()
gc.collect()
# Out:
# 386

# %%
model=torch.load('ECC_model_Tranfer.pt')

# %%
device=torch.device('cpu')
model=model.to(device)

# %%
import matplotlib.pyplot as plt
test_score,model,y_score,y_test=test(model, device,test_loader, args)
y_test=y_test.reshape(y_test.shape[0],1)
output_test=[]
target_test=[]
for i in range(y_score.shape[0]):
    output_test.append(y_score[i][0])
    target_test.append(y_test[i][0])
#print(output_test)
# y_score is in the form of torch tensor. So not converted to numpy properly
x=np.array([i for i in range(len(y_score))])
#print(len(x),y_score[0])
#print(y_score,x.shape)
#target=list(y_test[0])

#plt.ylim(0,0.3)
plt.title('Residual plot on Test Set')
plt.scatter(x,y=(np.array(output_test)-np.array(target_test)),color='red',label='Predicted',s=20)
plt.ylabel('Residual Values')
plt.xlabel('Data Points')
plt.show()
plt.scatter(x,y=target_test,color='blue',label='Actual Values',s=20)
plt.show()

print(y_test.shape,y_score.shape)
plt.scatter(target_test,output_test,s=10)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.show()
# Out:
# R2 Score Validation test set: [0.8362174]
# (686, 1) (686, 1)

# %%
# converting data to actual boiling points
#print(y_score[0][0])
for i in range(len(output_test)):
    # predicted
    output_test[i]=output_test[i]*(max_val-min_val)+min_val
    output_test[i]=output_test[i]*std+mean

    # Actual
    target_test[i]=target_test[i]*(max_val-min_val)+min_val
    target_test[i]=target_test[i]*std+mean

# %%
plt.scatter(target_test,output_test,s=10)
plt.plot([0,1000],[0,1000],color='black')
plt.plot([0,900],[0,1000],color='black',linestyle='dashed',label='10 Percent error Line') # +10 % error
plt.plot([0,1000],[0,900],color='black',linestyle='dashed') # -10 % error
plt.xlabel("Actual Boiling Point Values")
plt.ylabel("Predicted Boiling Point Values")
plt.ylim(0,1000)
plt.xlim(0,1000)
plt.legend()
plt.title('Parity Plot on Test Set')
plt.text(500,100,s=f'R2 Score = {test_score}')
plt.show()

# %%
# Save test 
test_data= pd.DataFrame()
test_data['ECC Outliers removed Actual Boiling Point']=target_test
test_data['ECC Outliers removed Predicted Boiling Point']=output_test
test_data.to_csv('../data/Results/Transfer_Learning_Test_values.csv')

# %%
# Train set predictions save
train_loader_pred = DataLoader(train_X, batch_size=len(train_X), shuffle=False, drop_last=True)
len(train_X)
# Out:
# 6167

# %%
import gc

torch.cuda.empty_cache()
gc.collect()
# Out:
# 10977

# %%
import matplotlib.pyplot as plt
train_score,model,y_score,y_test=test(model, device,train_loader_pred, args)
y_test=y_test.reshape(y_test.shape[0],1)
output_test=[]
target_test=[]
for i in range(y_score.shape[0]):
    output_test.append(y_score[i][0])
    target_test.append(y_test[i][0])
print(len(output_test))
# y_score is in the form of torch tensor. So not converted to numpy properly
x=np.array([i for i in range(len(y_score))])
#print(len(x),y_score[0])
#print(y_score,x.shape)
#target=list(y_test[0])

#plt.ylim(0,0.3)
plt.title('Residual plot on Train Set')
plt.scatter(x,y=(np.array(output_test)-np.array(target_test)),color='red',label='Predicted',s=20)
plt.ylabel('Residual Values')
plt.xlabel('Data Points')
plt.show()
plt.scatter(x,y=target_test,color='blue',label='Actual Values',s=20)
plt.show()

#print(y_test.shape,y_score.shape)
plt.scatter(target_test,output_test,s=10)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.show()
# Out:
# R2 Score Validation test set: [0.88993573]
# 6167

# %%
# converting data to actual boiling points
#print(y_score[0][0])
for i in range(len(output_test)):
    # predicted
    output_test[i]=output_test[i]*(max_val-min_val)+min_val
    output_test[i]=output_test[i]*std+mean

    # Actual
    target_test[i]=target_test[i]*(max_val-min_val)+min_val
    target_test[i]=target_test[i]*std+mean

# %%
plt.scatter(output_test,target_test,s=10)
plt.plot([0,1000],[0,1000],color='black')
plt.plot([0,900],[0,1000],color='black',linestyle='dashed',label='10 percent error line') # +10 % error
plt.plot([0,1000],[0,900],color='black',linestyle='dashed') # -10 % error
plt.ylim(0,1000)
plt.xlim(0,1000)
plt.xlabel("Actual Boiling Point Values")
plt.ylabel("Predicted Boiling Point Values")
plt.text(500,100,s=f'R2 Score = {train_score}')
plt.legend()
plt.title('Parity Plot on Train Set')
plt.show()

# %%
# Save train
test_data= pd.DataFrame()
test_data['ECC Outliers removed Actual Boiling Point']=target_test
test_data['ECC Outliers removed Predicted Boiling Point']=output_test
test_data.to_csv('../data/Results/Transfer_Learning_Train_values.csv')
